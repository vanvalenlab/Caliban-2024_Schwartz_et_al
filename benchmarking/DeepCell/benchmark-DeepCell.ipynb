# %% [markdown]
# # 1. Inference

# %%
import os
import sys

import numpy as np
import tensorflow as tf

from deepcell.applications import NuclearSegmentation, CellTracking
from deepcell_tracking.trk_io import load_trks

sys.path.append('/publication-tracking/benchmarking')
import utils

# %%
source_data = '/publication-tracking/data/test.trks'

data_dir = '/publication-tracking/benchmarking/DeepCell/data'
gt_seg_dir = os.path.join(data_dir, 'SEG_GT')
pred_seg_dir = os.path.join(data_dir, 'SEG_PRED')

for d in [data_dir, gt_seg_dir, pred_seg_dir]:
    if not os.path.exists(d):
        os.makedirs(d)
        
model_urls = {
    'NuclearSegmentation': 'https://deepcell-data.s3-us-west-1.amazonaws.com/saved-models/NuclearSegmentation-7.tar.gz',
    'NuclearTrackingNE': 'https://deepcell-data.s3-us-west-1.amazonaws.com/saved-models/NuclearTrackingNE-7.tar.gz',
    'NuclearTrackingInf': 'https://deepcell-data.s3-us-west-1.amazonaws.com/saved-models/NuclearTrackingInf-7.tar.gz'
}

# %%
# Load test data
data = load_trks(source_data)

# %%
# Download and load each model
models = {}
for m, url in model_urls.items():
    archive_path = tf.keras.utils.get_file(f'{m}.tgz', url, extract=True, cache_subdir='models')
    model_path = os.path.splitext(archive_path)[0]
    model = tf.keras.models.load_model(model_path)
    models[m] = model
# Out:
# 2022-11-17 23:46:52.323004: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-17 23:46:53.109959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10415 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0a:00.0, compute capability: 6.1
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
# Load segmentation and tracking applications
app_seg = NuclearSegmentation(models['NuclearSegmentation'])
app_trk = CellTracking(models['NuclearTrackingInf'], models['NuclearTrackingNE'])

# %%
for batch_no in range(len(data['lineages'])):
    print(batch_no)
    
    # Pull out relevant data for this batch
    X = data['X'][batch_no]
    y = data['y'][batch_no]
    lineage = data['lineages'][batch_no]
    
    # Correct discontiguous tracks, which are not allowed by CTC
    y, lineage = utils.convert_to_contiguous(y, lineage)

    # Determine position of zero padding for removal
    slc = utils.find_zero_padding(X)
    X = X[slc]
    y = y[slc]

    # Determine which frames are zero padding
    frames = np.sum(y, axis=(1,2)) # True if image not blank
    good_frames = np.where(frames)[0]
    X = X[:len(good_frames)]
    y = y[:len(good_frames)]
    
    # Generate tracks on GT segmentations
    track_gt = app_trk.track(X, y)
    track_gt['y_tracked'], track_gt['tracks'] = utils.convert_to_contiguous(track_gt['y_tracked'], track_gt['tracks'])
    utils.save_ctc_res(gt_seg_dir, batch_no + 1, track_gt['y_tracked'][..., 0], track_gt['tracks'])
    utils.save_ctc_gt(gt_seg_dir, batch_no + 1, y[..., 0], lineage)
    
    # Generate tracks on predicted segmentations
    y_pred = app_seg.predict(y)
    track_pred = app_trk.track(X, y_pred)
    track_pred['y_tracked'], track_pred['tracks'] = utils.convert_to_contiguous(track_pred['y_tracked'], track_pred['tracks'])
    utils.save_ctc_res(pred_seg_dir, batch_no + 1, track_pred['y_tracked'][..., 0], track_pred['tracks'])
    utils.save_ctc_gt(pred_seg_dir, batch_no + 1, y[..., 0], lineage)
# Out:
# 0
# 2022-11-17 23:48:19.131720: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8100
# /usr/local/lib/python3.8/dist-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0. Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# 1
# /usr/local/lib/python3.8/dist-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0. Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# 2
# /usr/local/lib/python3.8/dist-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0. Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# 3
# /usr/local/lib/python3.8/dist-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0. Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# 4
# /usr/local/lib/python3.8/dist-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0. Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# 5
# /usr/local/lib/python3.8/dist-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0. Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# 6
# /usr/local/lib/python3.8/dist-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0. Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# 7
# /usr/local/lib/python3.8/dist-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0. Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# 8
# /usr/local/lib/python3.8/dist-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0. Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# 9
# /usr/local/lib/python3.8/dist-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0. Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# 10
# /usr/local/lib/python3.8/dist-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0. Please use `footprint` instead.
#   markers = h_maxima(image=maxima,
# 11
# /usr/local/lib/python3.8/dist-packages/deepcell_toolbox/deep_watershed.py:179: FutureWarning: `selem` is a deprecated argument name for `h_maxima`. It will be removed in version 1.0. Please use `footprint` instead.
#   markers = h_maxima(image=maxima,

# %% [markdown]
# # 2. Evaluation

# %%
import glob
import os
import re
import subprocess

import numpy as np
import pandas as pd

from deepcell_tracking.metrics import TrackingMetrics

# %%
data_dir = '/publication-tracking/benchmarking/DeepCell/data'
gt_seg_dir = os.path.join(data_dir, 'SEG_GT')
pred_seg_dir = os.path.join(data_dir, 'SEG_PRED')

pattern = re.compile('\d{3}_GT')
data_ids = [f.split('_')[0] for f in os.listdir(gt_seg_dir) if pattern.fullmatch(f)]

node_match_threshold = 0.6

ctc_software = '/publication-tracking/benchmarking/CTC_Evaluation_Software'
operating_system = 'Linux' # or 'Mac' or 'Win'
num_digits = '3'

# %%
benchmarks = []

for results_dir, s in zip([gt_seg_dir, pred_seg_dir], ['GT', 'Deepcell']):
    for data_id in data_ids:
        results = {
            'model': f'Deepcell - {s}',
            'data_id': os.path.splitext(data_id)[0]
        }
        gt_dir = os.path.join(results_dir, f'{data_id}_GT/TRA')
        res_dir = os.path.join(results_dir, f'{data_id}_RES')
        
        # Deepcell benchmarking
        m = TrackingMetrics.from_isbi_dirs(gt_dir, res_dir, threshold=node_match_threshold)
        results.update(m.stats)
        
        # CTC metrics
        for metric, path in [('DET', 'DETMeasure'), ('SEG', 'SEGMeasure'), ('TRA', 'TRAMeasure')]:
            p = subprocess.run([os.path.join(ctc_software, operating_system, path), results_dir, data_id, num_digits],
                               stdout=subprocess.PIPE)
            outstring = p.stdout
            
            try:
                val = float(outstring.decode('utf-8').split()[-1])
                results[metric] = val
            except:
                print('Benchmarking failure', path, results_dir, data_id)
                print(outstring.decode('utf-8'))
        
        benchmarks.append(results)

df = pd.DataFrame(benchmarks)
df.to_csv('benchmarks.csv')
# Out:
# missed node 1_29 division completely
# missed node 29_29 division completely
# missed node 57_10 division completely
# missed node 60_0 division completely
# 18_16 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 5_6 division completely
# missed node 121_42 division completely
# missed node 144_28 division completely
# missed node 26_25 division completely
# missed node 1_29 division completely
# missed node 3_23 division completely
# 29_29 out degree = 1, daughters mismatch.
# corrected division 3_23 as a frameshift division not an error
# missed node 8_18 division completely
# missed node 10_19 division completely
# 15_17 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 29_17 division completely
# missed node 60_34 division completely
# missed node 76_7 division completely
# 82_17 out degree = 2, daughters mismatch, gt and res degree equal.
# 83_18 out degree = 2, parents mismatch, gt and res degree equal.
# corrected division 10_19 as a frameshift division not an error
# corrected division 60_34 as a frameshift division not an error
# corrected division 76_7 as a frameshift division not an error
# missed node 1_48 division completely
# missed node 6_16 division completely
# missed node 23_66 division completely
# missed node 48_6 division completely
# missed node 57_10 division completely
# missed node 60_0 division completely
# corrected division 48_6 as a frameshift division not an error
# corrected division 6_16 as a frameshift division not an error
# missed node 5_53 division completely
# missed node 9_38 division completely
# missed node 12_31 division completely
# missed node 14_35 division completely
# 18_16 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 22_24 division completely
# 23_17 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 25_37 division completely
# 30_28 out degree = 2, daughters mismatch, gt and res degree equal.
# 35_29 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 47_32 division completely
# missed node 68_23 division completely
# missed node 71_18 division completely
# 72_54 out degree = 2, daughters mismatch, gt and res degree equal.
# 76_34 out degree = 2, daughters mismatch, gt and res degree equal.
# 79_28 out degree = 3, daughters mismatch.
# 86_26 out degree = 1, daughters mismatch.
# missed node 91_51 division completely
# 96_17 out degree = 2, daughters mismatch, gt and res degree equal.
# 113_54 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 119_22 division completely
# corrected division 9_38 as a frameshift division not an error
# corrected division 47_32 as a frameshift division not an error
# corrected division 71_18 as a frameshift division not an error
# corrected division 119_22 as a frameshift division not an error
# corrected division 22_24 as a frameshift division not an error
# corrected division 91_51 as a frameshift division not an error
# corrected division 5_53 as a frameshift division not an error
# corrected division 68_23 as a frameshift division not an error
# missed node 37_35 division completely
# missed node 41_26 division completely
# missed node 43_4 division completely
# missed node 54_28 division completely
# missed node 73_5 division completely
# corrected division 54_28 as a frameshift division not an error
# corrected division 73_5 as a frameshift division not an error
# missed node 5_6 division completely
# missed node 10_66 division completely
# missed node 15_66 division completely
# missed node 16_9 division completely
# missed node 28_39 division completely
# missed node 30_37 division completely
# 48_44 out degree = 2, parents mismatch, gt and res degree equal.
# 51_28 out degree = 2, daughters mismatch, gt and res degree equal.
# 54_2 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 57_49 division completely
# missed node 62_3 division completely
# 66_12 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 70_52 division completely
# missed node 80_61 division completely
# missed node 88_27 division completely
# missed node 93_10 division completely
# 95_52 out degree = 1, daughters mismatch.
# missed node 104_34 division completely
# missed node 112_6 division completely
# missed node 121_42 division completely
# 125_22 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 127_51 division completely
# missed node 128_43 division completely
# missed node 132_23 division completely
# missed node 135_25 division completely
# missed node 144_28 division completely
# missed node 152_62 division completely
# missed node 163_66 division completely
# missed node 185_49 division completely
# corrected division 80_61 as a frameshift division not an error
# corrected division 93_10 as a frameshift division not an error
# corrected division 163_66 as a frameshift division not an error
# corrected division 112_6 as a frameshift division not an error
# corrected division 127_51 as a frameshift division not an error
# corrected division 185_49 as a frameshift division not an error
# corrected division 152_62 as a frameshift division not an error
# corrected division 128_43 as a frameshift division not an error
# corrected division 132_23 as a frameshift division not an error
# missed node 26_25 division completely

# %%
df
# Out:
#                   model data_id  correct_division  mismatch_division  \
# 0         Deepcell - GT     003                 6                  0
# 1         Deepcell - GT     005                 2                  0
# 2         Deepcell - GT     012                16                  0
# 3         Deepcell - GT     007                 1                  0
# 4         Deepcell - GT     008                18                  0
# 5         Deepcell - GT     010                53                  1
# 6         Deepcell - GT     011                15                  0
# 7         Deepcell - GT     002                 1                  0
# 8         Deepcell - GT     004                 1                  0
# 9         Deepcell - GT     009                54                  0
# 10        Deepcell - GT     006                 0                  0
# 11        Deepcell - GT     001                 2                  0
# 12  Deepcell - Deepcell     003                 6                  1
# 13  Deepcell - Deepcell     005                 2                  0
# 14  Deepcell - Deepcell     012                11                  3
# 15  Deepcell - Deepcell     007                 0                  0
# 16  Deepcell - Deepcell     008                17                  0
# 17  Deepcell - Deepcell     010                41                 10
# 18  Deepcell - Deepcell     011                12                  0
# 19  Deepcell - Deepcell     002                 1                  0
# 20  Deepcell - Deepcell     004                 1                  0
# 21  Deepcell - Deepcell     009                37                  6
# 22  Deepcell - Deepcell     006                 0                  0
# 23  Deepcell - Deepcell     001                 2                  0
#
#     false_positive_division  false_negative_division  total_divisions  aa_tp  \
# 0                         0                        2                8   2050
# 1                         0                        0                2    690
# 2                         0                        0               16   9565
# 3                         0                        0                1    195
# 4                         0                        2               20   4945
# 5                         0                        0               54   9008
# 6                         0                        0               15   3825
# 7                         0                        0                1   1075
# 8                         0                        0                1    521
# 9                         3                        3               57  14678
# 10                        0                        0                0    359
# 11                        0                        1                3    997
# 12                        0                        1                8   1967
# 13                        0                        0                2    658
# 14                        5                        2               16   8015
# 15                        0                        1                1    195
# 16                        1                        3               20   4839
# 17                        3                        3               54   8168
# 18                        2                        3               15   3616
# 19                        0                        0                1   1013
# 20                        0                        0                1    521
# 21                        4                       14               57  11825
# 22                        0                        0                0    343
# 23                        0                        1                3    961
#
#     aa_total  te_tp  te_total       DET       SEG       TRA
# 0       2055   2117      2122  1.000000  1.000000  0.999794
# 1        690    712       712  1.000000  1.000000  1.000000
# 2       9796   9866     10097  1.000000  1.000000  0.999036
# 3        199    202       206  1.000000  1.000000  0.999365
# 4       4945   5056      5056  1.000000  1.000000  0.999966
# 5       9090   9275      9357  1.000000  1.000000  0.999581
# 6       3833   3967      3975  1.000000  1.000000  0.999857
# 7       1075   1109      1109  1.000000  1.000000  1.000000
# 8        521    540       540  1.000000  1.000000  1.000000
# 9      14806  15046     15174  1.000000  1.000000  0.999773
# 10       383    373       397  1.000000  1.000000  0.998350
# 11       997   1030      1030  1.000000  1.000000  0.999915
# 12      2055   2034      2122  0.988219  0.899966  0.986948
# 13       690    680       712  0.987360  0.888588  0.986031
# 14      9796   8310     10097  0.939675  0.761327  0.919965
# 15       199    200       206  0.997573  0.912724  0.995977
# 16      4945   4950      5056  0.993671  0.896286  0.992927
# 17      9090   8435      9357  0.965844  0.799674  0.956164
# 18      3833   3757      3975  0.972453  0.805288  0.962092
# 19      1075   1047      1109  0.984671  0.880648  0.982724
# 20       521    539       540  0.997963  0.900054  0.998221
# 21     14806  12192     15174  0.914690  0.789928  0.899325
# 22       383    357       397  0.928212  0.798640  0.903950
# 23       997    994      1030  0.965049  0.871110  0.964331
