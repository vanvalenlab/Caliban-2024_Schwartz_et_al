# %% [markdown]
# <div class="alert alert-block alert-info"> <b>NOTE</b> Please select the kernel <code>Python [conda env: deepcell]</code> for this notebook. </div>

# %% [markdown]
# # 1. Inference

# %%
import os
import sys

import numpy as np
import tensorflow as tf

from deepcell.applications import NuclearSegmentation, CellTracking
from deepcell_tracking.trk_io import load_trks

sys.path.append('..')
import utils

# %%
gpus = tf.config.list_physical_devices('GPU')
tf.config.set_visible_devices(gpus[0], 'GPU')

# %%
data_dir = 'ctc-data'
gt_seg_dir = os.path.join(data_dir, 'SEG_GT')
pred_seg_dir = os.path.join(data_dir, 'SEG_PRED')

for d in [data_dir, gt_seg_dir, pred_seg_dir]:
    if not os.path.exists(d):
        os.makedirs(d)

# %%
files = ['../../data/Fluo-N2DL-Hela-test/Fluo-N2DL-HeLa-test-01.trk', '../../data/Fluo-N2DL-Hela-test/Fluo-N2DL-HeLa-test-02.trk']
X, y, lineages = [], [], []
for f in files:
    data = load_trks(f)
    X.append(data['X'])
    y.append(data['y'])
    lineages.append(data['lineages'][0])

data = {
    'X': np.stack(X, axis=0),
    'y': np.stack(y, axis=0),
    'lineages': lineages
}

# %%
# Load segmentation and tracking applications
app_seg = NuclearSegmentation.from_version(version='1.1')
app_trk = CellTracking.from_version(version='1.1')
# Out:
# INFO:root:Checking for cached data
# INFO:root:Checking NuclearSegmentation-8.tar.gz against provided file_hash...
# INFO:root:NuclearSegmentation-8.tar.gz with hash 507be21f0e34e59adae689f58cc03ccb already available.
# INFO:root:Extracting /home/msschwar/.deepcell/models/NuclearSegmentation-8.tar.gz
# INFO:root:Successfully extracted /home/msschwar/.deepcell/models/NuclearSegmentation-8.tar.gz into /home/msschwar/.deepcell/models
# 2024-07-09 16:01:09.400563: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-09 16:01:09.533327: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46873 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# INFO:root:Checking for cached data
# INFO:root:Checking NuclearTrackingNE-8.tar.gz against provided file_hash...
# INFO:root:NuclearTrackingNE-8.tar.gz with hash 79188d7ae32b40b5bd0ad0f2ac2b53c4 already available.
# INFO:root:Extracting /home/msschwar/.deepcell/models/NuclearTrackingNE-8.tar.gz
# INFO:root:Successfully extracted /home/msschwar/.deepcell/models/NuclearTrackingNE-8.tar.gz into /home/msschwar/.deepcell/models
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# INFO:root:Checking for cached data
# INFO:root:Checking NuclearTrackingInf-8.tar.gz against provided file_hash...
# INFO:root:NuclearTrackingInf-8.tar.gz with hash ec07d8c0770453e738f8699ceede78e7 already available.
# INFO:root:Extracting /home/msschwar/.deepcell/models/NuclearTrackingInf-8.tar.gz
# INFO:root:Successfully extracted /home/msschwar/.deepcell/models/NuclearTrackingInf-8.tar.gz into /home/msschwar/.deepcell/models
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
for batch_no in range(len(data['lineages'])):
    print(batch_no)

    # Pull out relevant data for this batch
    X = data['X'][batch_no]
    y = data['y'][batch_no]
    lineage = data['lineages'][batch_no]

    # Correct discontiguous tracks, which are not allowed by CTC
    y, lineage = utils.convert_to_contiguous(y, lineage)

    # Determine position of zero padding for removal
    slc = utils.find_zero_padding(X)
    X = X[slc]
    y = y[slc]

    # Determine which frames are zero padding
    frames = np.sum(y, axis=(1,2)) # True if image not blank
    good_frames = np.where(frames)[0]
    X = X[:len(good_frames)]
    y = y[:len(good_frames)]

    # Generate tracks on GT segmentations
    track_gt = app_trk.track(X, y)
    track_gt['y_tracked'], track_gt['tracks'] = utils.convert_to_contiguous(track_gt['y_tracked'], track_gt['tracks'])
    utils.save_ctc_res(gt_seg_dir, batch_no + 1, track_gt['y_tracked'][..., 0], track_gt['tracks'])
    utils.save_ctc_gt(gt_seg_dir, batch_no + 1, y[..., 0], lineage)

    # Generate tracks on predicted segmentations
    y_pred = app_seg.predict(X)
    track_pred = app_trk.track(X, y_pred)
    track_pred['y_tracked'], track_pred['tracks'] = utils.convert_to_contiguous(track_pred['y_tracked'], track_pred['tracks'])
    utils.save_ctc_res(pred_seg_dir, batch_no + 1, track_pred['y_tracked'][..., 0], track_pred['tracks'])
    utils.save_ctc_gt(pred_seg_dir, batch_no + 1, y[..., 0], lineage)
# Out:
# 0
# INFO:CellTracker:Tracking frame 1
# INFO:CellTracker:Tracked frame 1 in 0.40225896798074245 s.
# INFO:CellTracker:Tracking frame 2
# WARNING:tensorflow:5 out of the last 560 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a4b11d93a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 560 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a4b11d93a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO:CellTracker:Created new track for cell 65.
# INFO:CellTracker:Detected division! Cell 65 is daughter of cell 5.
# INFO:CellTracker:Tracked frame 2 in 0.35272837919183075 s.
# INFO:CellTracker:Tracking frame 3
# WARNING:tensorflow:6 out of the last 561 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a4b11d93a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 561 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a4b11d93a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO:CellTracker:Created new track for cell 67.
# INFO:CellTracker:Detected division! Cell 67 is daughter of cell 65.
# INFO:CellTracker:Tracked frame 3 in 0.3535239868797362 s.
# INFO:CellTracker:Tracking frame 4
# INFO:CellTracker:Created new track for cell 68.
# INFO:CellTracker:Detected division! Cell 68 is daughter of cell 9.
# INFO:CellTracker:Created new track for cell 69.
# INFO:CellTracker:Detected division! Cell 69 is daughter of cell 13.
# INFO:CellTracker:Created new track for cell 70.
# INFO:CellTracker:Detected division! Cell 70 is daughter of cell 13.
# INFO:CellTracker:Created new track for cell 71.
# INFO:CellTracker:Detected division! Cell 71 is daughter of cell 9.
# INFO:CellTracker:Tracked frame 4 in 0.35425032395869493 s.
# INFO:CellTracker:Tracking frame 5
# INFO:CellTracker:Tracked frame 5 in 0.10237803612835705 s.
# INFO:CellTracker:Tracking frame 6
# INFO:CellTracker:Created new track for cell 72.
# INFO:CellTracker:Created new track for cell 73.
# INFO:CellTracker:Detected division! Cell 73 is daughter of cell 10.
# INFO:CellTracker:Created new track for cell 74.
# INFO:CellTracker:Created new track for cell 75.
# INFO:CellTracker:Detected division! Cell 75 is daughter of cell 7.
# INFO:CellTracker:Created new track for cell 76.
# INFO:CellTracker:Created new track for cell 77.
# INFO:CellTracker:Tracked frame 6 in 0.11725243809632957 s.
# INFO:CellTracker:Tracking frame 7
# INFO:CellTracker:Tracked frame 7 in 0.10541081591509283 s.
# INFO:CellTracker:Tracking frame 8
# INFO:CellTracker:Created new track for cell 78.
# INFO:CellTracker:Detected division! Cell 78 is daughter of cell 6.
# INFO:CellTracker:Created new track for cell 79.
# INFO:CellTracker:Detected division! Cell 79 is daughter of cell 6.
# INFO:CellTracker:Tracked frame 8 in 0.11485632602125406 s.
# INFO:CellTracker:Tracking frame 9
# INFO:CellTracker:Created new track for cell 80.
# INFO:CellTracker:Tracked frame 9 in 0.1082784968893975 s.
# INFO:CellTracker:Tracking frame 10
# INFO:CellTracker:Created new track for cell 81.
# INFO:CellTracker:Detected division! Cell 81 is daughter of cell 52.
# INFO:CellTracker:Created new track for cell 82.
# INFO:CellTracker:Detected division! Cell 82 is daughter of cell 49.
# INFO:CellTracker:Created new track for cell 83.
# INFO:CellTracker:Detected division! Cell 83 is daughter of cell 49.
# INFO:CellTracker:Created new track for cell 84.
# INFO:CellTracker:Detected division! Cell 84 is daughter of cell 47.
# INFO:CellTracker:Created new track for cell 85.
# INFO:CellTracker:Detected division! Cell 85 is daughter of cell 52.
# INFO:CellTracker:Created new track for cell 86.
# INFO:CellTracker:Detected division! Cell 86 is daughter of cell 47.
# INFO:CellTracker:Created new track for cell 87.
# INFO:CellTracker:Created new track for cell 88.
# INFO:CellTracker:Tracked frame 10 in 0.1267814659513533 s.
# INFO:CellTracker:Tracking frame 11
# INFO:CellTracker:Created new track for cell 89.
# INFO:CellTracker:Created new track for cell 90.
# INFO:CellTracker:Created new track for cell 91.
# INFO:CellTracker:Detected division! Cell 91 is daughter of cell 51.
# INFO:CellTracker:Created new track for cell 92.
# INFO:CellTracker:Detected division! Cell 92 is daughter of cell 48.
# INFO:CellTracker:Created new track for cell 93.
# INFO:CellTracker:Detected division! Cell 93 is daughter of cell 64.
# INFO:CellTracker:Created new track for cell 94.
# INFO:CellTracker:Created new track for cell 95.
# INFO:CellTracker:Created new track for cell 96.
# INFO:CellTracker:Detected division! Cell 96 is daughter of cell 64.
# INFO:CellTracker:Tracked frame 11 in 0.1284728110767901 s.
# INFO:CellTracker:Tracking frame 12
# INFO:CellTracker:Created new track for cell 98.
# INFO:CellTracker:Created new track for cell 99.
# INFO:CellTracker:Tracked frame 12 in 0.11658501019701362 s.
# INFO:CellTracker:Tracking frame 13
# INFO:CellTracker:Tracked frame 13 in 0.11620585108175874 s.
# INFO:CellTracker:Tracking frame 14
# INFO:CellTracker:Created new track for cell 100.
# INFO:CellTracker:Detected division! Cell 100 is daughter of cell 8.
# INFO:CellTracker:Created new track for cell 101.
# INFO:CellTracker:Detected division! Cell 101 is daughter of cell 54.
# INFO:CellTracker:Created new track for cell 102.
# INFO:CellTracker:Detected division! Cell 102 is daughter of cell 54.
# INFO:CellTracker:Created new track for cell 103.
# INFO:CellTracker:Created new track for cell 104.
# INFO:CellTracker:Detected division! Cell 104 is daughter of cell 8.
# INFO:CellTracker:Created new track for cell 105.
# INFO:CellTracker:Tracked frame 14 in 0.13230391801334918 s.
# INFO:CellTracker:Tracking frame 15
# INFO:CellTracker:Created new track for cell 106.
# INFO:CellTracker:Detected division! Cell 106 is daughter of cell 42.
# INFO:CellTracker:Created new track for cell 107.
# INFO:CellTracker:Detected division! Cell 107 is daughter of cell 29.
# INFO:CellTracker:Created new track for cell 108.
# INFO:CellTracker:Detected division! Cell 108 is daughter of cell 29.
# INFO:CellTracker:Created new track for cell 109.
# INFO:CellTracker:Detected division! Cell 109 is daughter of cell 42.
# INFO:CellTracker:Tracked frame 15 in 0.1354017781559378 s.
# INFO:CellTracker:Tracking frame 16
# INFO:CellTracker:Created new track for cell 110.
# INFO:CellTracker:Detected division! Cell 110 is daughter of cell 56.
# INFO:CellTracker:Created new track for cell 111.
# INFO:CellTracker:Detected division! Cell 111 is daughter of cell 44.
# INFO:CellTracker:Created new track for cell 112.
# INFO:CellTracker:Detected division! Cell 112 is daughter of cell 44.
# INFO:CellTracker:Created new track for cell 113.
# INFO:CellTracker:Detected division! Cell 113 is daughter of cell 56.
# INFO:CellTracker:Created new track for cell 114.
# INFO:CellTracker:Tracked frame 16 in 0.13808829011395574 s.
# INFO:CellTracker:Tracking frame 17
# INFO:CellTracker:Created new track for cell 115.
# INFO:CellTracker:Detected division! Cell 115 is daughter of cell 31.
# INFO:CellTracker:Created new track for cell 116.
# INFO:CellTracker:Detected division! Cell 116 is daughter of cell 46.
# INFO:CellTracker:Created new track for cell 117.
# INFO:CellTracker:Detected division! Cell 117 is daughter of cell 50.
# INFO:CellTracker:Created new track for cell 118.
# INFO:CellTracker:Created new track for cell 119.
# INFO:CellTracker:Detected division! Cell 119 is daughter of cell 31.
# INFO:CellTracker:Tracked frame 17 in 0.13602332607842982 s.
# INFO:CellTracker:Tracking frame 18
# INFO:CellTracker:Created new track for cell 122.
# INFO:CellTracker:Detected division! Cell 122 is daughter of cell 38.
# INFO:CellTracker:Created new track for cell 123.
# INFO:CellTracker:Detected division! Cell 123 is daughter of cell 58.
# INFO:CellTracker:Created new track for cell 124.
# INFO:CellTracker:Detected division! Cell 124 is daughter of cell 38.
# INFO:CellTracker:Created new track for cell 125.
# INFO:CellTracker:Detected division! Cell 125 is daughter of cell 58.
# INFO:CellTracker:Tracked frame 18 in 0.1377627809997648 s.
# INFO:CellTracker:Tracking frame 19
# INFO:CellTracker:Created new track for cell 126.
# INFO:CellTracker:Tracked frame 19 in 0.12769748293794692 s.
# INFO:CellTracker:Tracking frame 20
# INFO:CellTracker:Tracked frame 20 in 0.12798440200276673 s.
# INFO:CellTracker:Tracking frame 21
# INFO:CellTracker:Created new track for cell 127.
# INFO:CellTracker:Created new track for cell 128.
# INFO:CellTracker:Detected division! Cell 128 is daughter of cell 43.
# INFO:CellTracker:Created new track for cell 129.
# INFO:CellTracker:Created new track for cell 130.
# INFO:CellTracker:Detected division! Cell 130 is daughter of cell 2.
# INFO:CellTracker:Tracked frame 21 in 0.14091213000938296 s.
# INFO:CellTracker:Tracking frame 22
# INFO:CellTracker:Created new track for cell 133.
# INFO:CellTracker:Detected division! Cell 133 is daughter of cell 28.
# INFO:CellTracker:Created new track for cell 134.
# INFO:CellTracker:Tracked frame 22 in 0.13691517291590571 s.
# INFO:CellTracker:Tracking frame 23
# INFO:CellTracker:Created new track for cell 136.
# INFO:CellTracker:Created new track for cell 137.
# INFO:CellTracker:Detected division! Cell 137 is daughter of cell 26.
# INFO:CellTracker:Tracked frame 23 in 0.14009725395590067 s.
# INFO:CellTracker:Tracking frame 24
# INFO:CellTracker:Created new track for cell 139.
# INFO:CellTracker:Created new track for cell 140.
# INFO:CellTracker:Created new track for cell 141.
# INFO:CellTracker:Created new track for cell 142.
# INFO:CellTracker:Detected division! Cell 142 is daughter of cell 37.
# INFO:CellTracker:Created new track for cell 143.
# INFO:CellTracker:Detected division! Cell 143 is daughter of cell 37.
# INFO:CellTracker:Tracked frame 24 in 0.14720958983525634 s.
# INFO:CellTracker:Tracking frame 25
# INFO:CellTracker:Created new track for cell 144.
# INFO:CellTracker:Created new track for cell 145.
# INFO:CellTracker:Created new track for cell 146.
# INFO:CellTracker:Detected division! Cell 146 is daughter of cell 41.
# INFO:CellTracker:Created new track for cell 147.
# INFO:CellTracker:Detected division! Cell 147 is daughter of cell 41.
# INFO:CellTracker:Tracked frame 25 in 0.14590951497666538 s.
# INFO:CellTracker:Tracking frame 26
# INFO:CellTracker:Created new track for cell 148.
# INFO:CellTracker:Detected division! Cell 148 is daughter of cell 21.
# INFO:CellTracker:Created new track for cell 149.
# INFO:CellTracker:Detected division! Cell 149 is daughter of cell 21.
# INFO:CellTracker:Created new track for cell 150.
# INFO:CellTracker:Detected division! Cell 150 is daughter of cell 12.
# INFO:CellTracker:Created new track for cell 151.
# INFO:CellTracker:Detected division! Cell 151 is daughter of cell 30.
# INFO:CellTracker:Created new track for cell 152.
# INFO:CellTracker:Detected division! Cell 152 is daughter of cell 23.
# INFO:CellTracker:Created new track for cell 153.
# INFO:CellTracker:Detected division! Cell 153 is daughter of cell 30.
# INFO:CellTracker:Created new track for cell 154.
# INFO:CellTracker:Detected division! Cell 154 is daughter of cell 23.
# INFO:CellTracker:Tracked frame 26 in 0.15978744905442 s.
# INFO:CellTracker:Tracking frame 27
# INFO:CellTracker:Created new track for cell 156.
# INFO:CellTracker:Created new track for cell 157.
# INFO:CellTracker:Detected division! Cell 157 is daughter of cell 59.
# INFO:CellTracker:Tracked frame 27 in 0.14925934304483235 s.
# INFO:CellTracker:Tracking frame 28
# INFO:CellTracker:Created new track for cell 159.
# INFO:CellTracker:Detected division! Cell 159 is daughter of cell 18.
# INFO:CellTracker:Created new track for cell 160.
# INFO:CellTracker:Detected division! Cell 160 is daughter of cell 57.
# INFO:CellTracker:Created new track for cell 161.
# INFO:CellTracker:Detected division! Cell 161 is daughter of cell 57.
# INFO:CellTracker:Tracked frame 28 in 0.14969295193441212 s.
# INFO:CellTracker:Tracking frame 29
# INFO:CellTracker:Tracked frame 29 in 0.1420661760494113 s.
# INFO:CellTracker:Tracking frame 30
# INFO:CellTracker:Created new track for cell 163.
# INFO:CellTracker:Created new track for cell 164.
# INFO:CellTracker:Detected division! Cell 164 is daughter of cell 53.
# INFO:CellTracker:Tracked frame 30 in 0.14800757798366249 s.
# INFO:CellTracker:Tracking frame 31
# INFO:CellTracker:Created new track for cell 166.
# INFO:CellTracker:Detected division! Cell 166 is daughter of cell 20.
# INFO:CellTracker:Tracked frame 31 in 0.15777826588600874 s.
# INFO:CellTracker:Tracking frame 32
# INFO:CellTracker:Created new track for cell 168.
# INFO:CellTracker:Detected division! Cell 168 is daughter of cell 80.
# INFO:CellTracker:Created new track for cell 169.
# INFO:CellTracker:Detected division! Cell 169 is daughter of cell 80.
# INFO:CellTracker:Tracked frame 32 in 0.15638063102960587 s.
# INFO:CellTracker:Tracking frame 33
# INFO:CellTracker:Created new track for cell 170.
# INFO:CellTracker:Detected division! Cell 170 is daughter of cell 33.
# INFO:CellTracker:Created new track for cell 171.
# INFO:CellTracker:Detected division! Cell 171 is daughter of cell 33.
# INFO:CellTracker:Created new track for cell 172.
# INFO:CellTracker:Detected division! Cell 172 is daughter of cell 63.
# INFO:CellTracker:Created new track for cell 173.
# INFO:CellTracker:Detected division! Cell 173 is daughter of cell 63.
# INFO:CellTracker:Tracked frame 33 in 0.15644115884788334 s.
# INFO:CellTracker:Tracking frame 34
# INFO:CellTracker:Created new track for cell 174.
# INFO:CellTracker:Created new track for cell 175.
# INFO:CellTracker:Detected division! Cell 175 is daughter of cell 22.
# INFO:CellTracker:Created new track for cell 176.
# INFO:CellTracker:Tracked frame 34 in 0.15553458291105926 s.
# INFO:CellTracker:Tracking frame 35
# INFO:CellTracker:Created new track for cell 178.
# INFO:CellTracker:Detected division! Cell 178 is daughter of cell 105.
# INFO:CellTracker:Created new track for cell 179.
# INFO:CellTracker:Tracked frame 35 in 0.1577524549793452 s.
# INFO:CellTracker:Tracking frame 36
# INFO:CellTracker:Tracked frame 36 in 0.16309939790517092 s.
# INFO:CellTracker:Tracking frame 37
# INFO:CellTracker:Created new track for cell 181.
# INFO:CellTracker:Detected division! Cell 181 is daughter of cell 16.
# INFO:CellTracker:Created new track for cell 182.
# INFO:CellTracker:Detected division! Cell 182 is daughter of cell 67.
# INFO:CellTracker:Created new track for cell 183.
# INFO:CellTracker:Detected division! Cell 183 is daughter of cell 67.
# INFO:CellTracker:Tracked frame 37 in 0.16237527993507683 s.
# INFO:CellTracker:Tracking frame 38
# INFO:CellTracker:Created new track for cell 185.
# INFO:CellTracker:Detected division! Cell 185 is daughter of cell 39.
# INFO:CellTracker:Created new track for cell 186.
# INFO:CellTracker:Detected division! Cell 186 is daughter of cell 39.
# INFO:CellTracker:Created new track for cell 187.
# INFO:CellTracker:Detected division! Cell 187 is daughter of cell 55.
# INFO:CellTracker:Created new track for cell 188.
# INFO:CellTracker:Created new track for cell 189.
# INFO:CellTracker:Detected division! Cell 189 is daughter of cell 87.
# INFO:CellTracker:Created new track for cell 190.
# INFO:CellTracker:Detected division! Cell 190 is daughter of cell 87.
# INFO:CellTracker:Tracked frame 38 in 0.1798590929247439 s.
# INFO:CellTracker:Tracking frame 39
# INFO:CellTracker:Created new track for cell 191.
# INFO:CellTracker:Tracked frame 39 in 0.15968937892466784 s.
# INFO:CellTracker:Tracking frame 40
# INFO:CellTracker:Created new track for cell 192.
# INFO:CellTracker:Detected division! Cell 192 is daughter of cell 66.
# INFO:CellTracker:Created new track for cell 193.
# INFO:CellTracker:Detected division! Cell 193 is daughter of cell 66.
# INFO:CellTracker:Created new track for cell 194.
# INFO:CellTracker:Tracked frame 40 in 0.16926591796800494 s.
# INFO:CellTracker:Tracking frame 41
# INFO:CellTracker:Created new track for cell 195.
# INFO:CellTracker:Detected division! Cell 195 is daughter of cell 68.
# INFO:CellTracker:Created new track for cell 196.
# INFO:CellTracker:Detected division! Cell 196 is daughter of cell 68.
# INFO:CellTracker:Created new track for cell 197.
# INFO:CellTracker:Detected division! Cell 197 is daughter of cell 71.
# INFO:CellTracker:Created new track for cell 198.
# INFO:CellTracker:Detected division! Cell 198 is daughter of cell 71.
# INFO:CellTracker:Created new track for cell 199.
# INFO:CellTracker:Tracked frame 41 in 0.17002090578898787 s.
# INFO:CellTracker:Tracking frame 42
# INFO:CellTracker:Created new track for cell 200.
# INFO:CellTracker:Detected division! Cell 200 is daughter of cell 14.
# INFO:CellTracker:Created new track for cell 201.
# INFO:CellTracker:Created new track for cell 202.
# INFO:CellTracker:Created new track for cell 203.
# INFO:CellTracker:Detected division! Cell 203 is daughter of cell 35.
# INFO:CellTracker:Created new track for cell 204.
# INFO:CellTracker:Detected division! Cell 204 is daughter of cell 14.
# INFO:CellTracker:Tracked frame 42 in 0.1774358309339732 s.
# INFO:CellTracker:Tracking frame 43
# INFO:CellTracker:Created new track for cell 206.
# INFO:CellTracker:Detected division! Cell 206 is daughter of cell 34.
# INFO:CellTracker:Created new track for cell 207.
# INFO:CellTracker:Detected division! Cell 207 is daughter of cell 36.
# INFO:CellTracker:Created new track for cell 208.
# INFO:CellTracker:Detected division! Cell 208 is daughter of cell 34.
# INFO:CellTracker:Created new track for cell 209.
# INFO:CellTracker:Detected division! Cell 209 is daughter of cell 36.
# INFO:CellTracker:Created new track for cell 210.
# INFO:CellTracker:Detected division! Cell 210 is daughter of cell 62.
# INFO:CellTracker:Created new track for cell 211.
# INFO:CellTracker:Detected division! Cell 211 is daughter of cell 204.
# INFO:CellTracker:Tracked frame 43 in 0.1808468101080507 s.
# INFO:CellTracker:Tracking frame 44
# INFO:CellTracker:Created new track for cell 213.
# INFO:CellTracker:Detected division! Cell 213 is daughter of cell 11.
# INFO:CellTracker:Created new track for cell 214.
# INFO:CellTracker:Detected division! Cell 214 is daughter of cell 99.
# INFO:CellTracker:Created new track for cell 215.
# INFO:CellTracker:Tracked frame 44 in 0.17265583807602525 s.
# INFO:CellTracker:Tracking frame 45
# INFO:CellTracker:Created new track for cell 218.
# INFO:CellTracker:Detected division! Cell 218 is daughter of cell 40.
# INFO:CellTracker:Created new track for cell 219.
# INFO:CellTracker:Detected division! Cell 219 is daughter of cell 176.
# INFO:CellTracker:Created new track for cell 220.
# INFO:CellTracker:Detected division! Cell 220 is daughter of cell 201.
# INFO:CellTracker:Created new track for cell 221.
# INFO:CellTracker:Detected division! Cell 221 is daughter of cell 176.
# INFO:CellTracker:Created new track for cell 222.
# INFO:CellTracker:Detected division! Cell 222 is daughter of cell 217.
# INFO:CellTracker:Tracked frame 45 in 0.18774341815151274 s.
# INFO:CellTracker:Tracking frame 46
# INFO:CellTracker:Created new track for cell 225.
# INFO:CellTracker:Detected division! Cell 225 is daughter of cell 15.
# INFO:CellTracker:Tracked frame 46 in 0.1777156109455973 s.
# INFO:CellTracker:Tracking frame 47
# INFO:CellTracker:Created new track for cell 227.
# INFO:CellTracker:Detected division! Cell 227 is daughter of cell 103.
# INFO:CellTracker:Tracked frame 47 in 0.16783020203001797 s.
# INFO:CellTracker:Tracking frame 48
# INFO:CellTracker:Created new track for cell 229.
# INFO:CellTracker:Detected division! Cell 229 is daughter of cell 121.
# INFO:CellTracker:Tracked frame 48 in 0.17216749885119498 s.
# INFO:CellTracker:Tracking frame 49
# INFO:CellTracker:Created new track for cell 231.
# INFO:CellTracker:Detected division! Cell 231 is daughter of cell 108.
# INFO:CellTracker:Tracked frame 49 in 0.171688640024513 s.
# INFO:CellTracker:Tracking frame 50
# INFO:CellTracker:Created new track for cell 233.
# INFO:CellTracker:Detected division! Cell 233 is daughter of cell 117.
# INFO:CellTracker:Created new track for cell 234.
# INFO:CellTracker:Created new track for cell 235.
# INFO:CellTracker:Detected division! Cell 235 is daughter of cell 141.
# INFO:CellTracker:Created new track for cell 236.
# INFO:CellTracker:Detected division! Cell 236 is daughter of cell 141.
# INFO:CellTracker:Tracked frame 50 in 0.18049858091399074 s.
# INFO:CellTracker:Tracking frame 51
# INFO:CellTracker:Created new track for cell 238.
# INFO:CellTracker:Detected division! Cell 238 is daughter of cell 25.
# INFO:CellTracker:Created new track for cell 239.
# INFO:CellTracker:Detected division! Cell 239 is daughter of cell 118.
# INFO:CellTracker:Created new track for cell 240.
# INFO:CellTracker:Created new track for cell 241.
# INFO:CellTracker:Created new track for cell 242.
# INFO:CellTracker:Tracked frame 51 in 0.19428679603151977 s.
# INFO:CellTracker:Tracking frame 52
# INFO:CellTracker:Created new track for cell 244.
# INFO:CellTracker:Detected division! Cell 244 is daughter of cell 24.
# INFO:CellTracker:Created new track for cell 245.
# INFO:CellTracker:Created new track for cell 246.
# INFO:CellTracker:Created new track for cell 247.
# INFO:CellTracker:Detected division! Cell 247 is daughter of cell 24.
# INFO:CellTracker:Tracked frame 52 in 0.18354807188734412 s.
# INFO:CellTracker:Tracking frame 53
# INFO:CellTracker:Created new track for cell 248.
# INFO:CellTracker:Detected division! Cell 248 is daughter of cell 70.
# INFO:CellTracker:Created new track for cell 249.
# INFO:CellTracker:Detected division! Cell 249 is daughter of cell 202.
# INFO:CellTracker:Created new track for cell 250.
# INFO:CellTracker:Detected division! Cell 250 is daughter of cell 202.
# INFO:CellTracker:Created new track for cell 251.
# INFO:CellTracker:Detected division! Cell 251 is daughter of cell 70.
# INFO:CellTracker:Tracked frame 53 in 0.19539519399404526 s.
# INFO:CellTracker:Tracking frame 54
# INFO:CellTracker:Created new track for cell 252.
# INFO:CellTracker:Created new track for cell 253.
# INFO:CellTracker:Detected division! Cell 253 is daughter of cell 106.
# INFO:CellTracker:Created new track for cell 254.
# INFO:CellTracker:Detected division! Cell 254 is daughter of cell 73.
# INFO:CellTracker:Created new track for cell 255.
# INFO:CellTracker:Detected division! Cell 255 is daughter of cell 73.
# INFO:CellTracker:Created new track for cell 256.
# INFO:CellTracker:Detected division! Cell 256 is daughter of cell 106.
# INFO:CellTracker:Created new track for cell 257.
# INFO:CellTracker:Detected division! Cell 257 is daughter of cell 92.
# INFO:CellTracker:Created new track for cell 258.
# INFO:CellTracker:Detected division! Cell 258 is daughter of cell 92.
# INFO:CellTracker:Tracked frame 54 in 0.2019331429619342 s.
# INFO:CellTracker:Tracking frame 55
# INFO:CellTracker:Created new track for cell 259.
# INFO:CellTracker:Detected division! Cell 259 is daughter of cell 112.
# INFO:CellTracker:Created new track for cell 260.
# INFO:CellTracker:Detected division! Cell 260 is daughter of cell 75.
# INFO:CellTracker:Created new track for cell 261.
# INFO:CellTracker:Detected division! Cell 261 is daughter of cell 119.
# INFO:CellTracker:Created new track for cell 262.
# INFO:CellTracker:Detected division! Cell 262 is daughter of cell 119.
# INFO:CellTracker:Created new track for cell 263.
# INFO:CellTracker:Detected division! Cell 263 is daughter of cell 179.
# INFO:CellTracker:Created new track for cell 264.
# INFO:CellTracker:Created new track for cell 265.
# INFO:CellTracker:Detected division! Cell 265 is daughter of cell 126.
# INFO:CellTracker:Created new track for cell 266.
# INFO:CellTracker:Detected division! Cell 266 is daughter of cell 112.
# INFO:CellTracker:Created new track for cell 267.
# INFO:CellTracker:Detected division! Cell 267 is daughter of cell 126.
# INFO:CellTracker:Created new track for cell 268.
# INFO:CellTracker:Detected division! Cell 268 is daughter of cell 179.
# INFO:CellTracker:Created new track for cell 269.
# INFO:CellTracker:Detected division! Cell 269 is daughter of cell 75.
# INFO:CellTracker:Tracked frame 55 in 0.22382098995149136 s.
# INFO:CellTracker:Tracking frame 56
# INFO:CellTracker:Created new track for cell 270.
# INFO:CellTracker:Detected division! Cell 270 is daughter of cell 123.
# INFO:CellTracker:Created new track for cell 271.
# INFO:CellTracker:Tracked frame 56 in 0.19116203696466982 s.
# INFO:CellTracker:Tracking frame 57
# INFO:CellTracker:Created new track for cell 273.
# INFO:CellTracker:Detected division! Cell 273 is daughter of cell 101.
# INFO:CellTracker:Created new track for cell 274.
# INFO:CellTracker:Detected division! Cell 274 is daughter of cell 61.
# INFO:CellTracker:Created new track for cell 275.
# INFO:CellTracker:Detected division! Cell 275 is daughter of cell 272.
# INFO:CellTracker:Created new track for cell 276.
# INFO:CellTracker:Detected division! Cell 276 is daughter of cell 102.
# INFO:CellTracker:Created new track for cell 277.
# INFO:CellTracker:Detected division! Cell 277 is daughter of cell 61.
# INFO:CellTracker:Created new track for cell 278.
# INFO:CellTracker:Detected division! Cell 278 is daughter of cell 125.
# INFO:CellTracker:Created new track for cell 279.
# INFO:CellTracker:Detected division! Cell 279 is daughter of cell 125.
# INFO:CellTracker:Created new track for cell 280.
# INFO:CellTracker:Detected division! Cell 280 is daughter of cell 101.
# INFO:CellTracker:Created new track for cell 281.
# INFO:CellTracker:Detected division! Cell 281 is daughter of cell 77.
# INFO:CellTracker:Created new track for cell 282.
# INFO:CellTracker:Created new track for cell 283.
# INFO:CellTracker:Created new track for cell 284.
# INFO:CellTracker:Detected division! Cell 284 is daughter of cell 77.
# INFO:CellTracker:Created new track for cell 285.
# INFO:CellTracker:Detected division! Cell 285 is daughter of cell 84.
# INFO:CellTracker:Tracked frame 57 in 0.24820273113436997 s.
# INFO:CellTracker:Tracking frame 58
# INFO:CellTracker:Created new track for cell 288.
# INFO:CellTracker:Created new track for cell 289.
# INFO:CellTracker:Detected division! Cell 289 is daughter of cell 85.
# INFO:CellTracker:Tracked frame 58 in 0.21070418297313154 s.
# INFO:CellTracker:Tracking frame 59
# INFO:CellTracker:Created new track for cell 291.
# INFO:CellTracker:Detected division! Cell 291 is daughter of cell 17.
# INFO:CellTracker:Created new track for cell 292.
# INFO:CellTracker:Created new track for cell 293.
# INFO:CellTracker:Tracked frame 59 in 0.202403720933944 s.
# INFO:CellTracker:Tracking frame 60
# INFO:CellTracker:Created new track for cell 295.
# INFO:CellTracker:Detected division! Cell 295 is daughter of cell 86.
# INFO:CellTracker:Created new track for cell 296.
# INFO:CellTracker:Detected division! Cell 296 is daughter of cell 69.
# INFO:CellTracker:Created new track for cell 297.
# INFO:CellTracker:Detected division! Cell 297 is daughter of cell 83.
# INFO:CellTracker:Tracked frame 60 in 0.22343538305722177 s.
# INFO:CellTracker:Tracking frame 61
# INFO:CellTracker:Created new track for cell 301.
# INFO:CellTracker:Detected division! Cell 301 is daughter of cell 130.
# INFO:CellTracker:Created new track for cell 302.
# INFO:CellTracker:Detected division! Cell 302 is daughter of cell 115.
# INFO:CellTracker:Created new track for cell 303.
# INFO:CellTracker:Tracked frame 61 in 0.20807681186124682 s.
# INFO:CellTracker:Tracking frame 62
# INFO:CellTracker:Created new track for cell 306.
# INFO:CellTracker:Detected division! Cell 306 is daughter of cell 116.
# INFO:CellTracker:Created new track for cell 307.
# INFO:CellTracker:Detected division! Cell 307 is daughter of cell 122.
# INFO:CellTracker:Created new track for cell 308.
# INFO:CellTracker:Detected division! Cell 308 is daughter of cell 124.
# INFO:CellTracker:Created new track for cell 309.
# INFO:CellTracker:Detected division! Cell 309 is daughter of cell 124.
# INFO:CellTracker:Created new track for cell 310.
# INFO:CellTracker:Detected division! Cell 310 is daughter of cell 242.
# INFO:CellTracker:Created new track for cell 311.
# INFO:CellTracker:Detected division! Cell 311 is daughter of cell 242.
# INFO:CellTracker:Created new track for cell 312.
# INFO:CellTracker:Created new track for cell 313.
# INFO:CellTracker:Detected division! Cell 313 is daughter of cell 116.
# INFO:CellTracker:Tracked frame 62 in 0.2313555460423231 s.
# INFO:CellTracker:Tracking frame 63
# INFO:CellTracker:Created new track for cell 314.
# INFO:CellTracker:Detected division! Cell 314 is daughter of cell 72.
# INFO:CellTracker:Created new track for cell 315.
# INFO:CellTracker:Detected division! Cell 315 is daughter of cell 72.
# INFO:CellTracker:Tracked frame 63 in 0.2034454569220543 s.
# INFO:CellTracker:Tracking frame 64
# INFO:CellTracker:Created new track for cell 316.
# INFO:CellTracker:Detected division! Cell 316 is daughter of cell 138.
# INFO:CellTracker:Created new track for cell 317.
# INFO:CellTracker:Detected division! Cell 317 is daughter of cell 131.
# INFO:CellTracker:Created new track for cell 318.
# INFO:CellTracker:Tracked frame 64 in 0.20799910300411284 s.
# INFO:CellTracker:Tracking frame 65
# INFO:CellTracker:Created new track for cell 321.
# INFO:CellTracker:Created new track for cell 322.
# INFO:CellTracker:Detected division! Cell 322 is daughter of cell 111.
# INFO:CellTracker:Created new track for cell 323.
# INFO:CellTracker:Detected division! Cell 323 is daughter of cell 111.
# INFO:CellTracker:Tracked frame 65 in 0.2076100839767605 s.
# INFO:CellTracker:Tracking frame 66
# INFO:CellTracker:Created new track for cell 324.
# INFO:CellTracker:Detected division! Cell 324 is daughter of cell 137.
# INFO:CellTracker:Created new track for cell 325.
# INFO:CellTracker:Detected division! Cell 325 is daughter of cell 104.
# INFO:CellTracker:Created new track for cell 326.
# INFO:CellTracker:Detected division! Cell 326 is daughter of cell 104.
# INFO:CellTracker:Tracked frame 66 in 0.21808571903966367 s.
# INFO:CellTracker:Tracking frame 67
# INFO:CellTracker:Created new track for cell 328.
# INFO:CellTracker:Detected division! Cell 328 is daughter of cell 74.
# INFO:CellTracker:Created new track for cell 329.
# INFO:CellTracker:Created new track for cell 330.
# INFO:CellTracker:Tracked frame 67 in 0.21526862820610404 s.
# INFO:CellTracker:Tracking frame 68
# INFO:CellTracker:Created new track for cell 332.
# INFO:CellTracker:Detected division! Cell 332 is daughter of cell 120.
# INFO:CellTracker:Created new track for cell 333.
# INFO:CellTracker:Detected division! Cell 333 is daughter of cell 120.
# INFO:CellTracker:Created new track for cell 334.
# INFO:CellTracker:Detected division! Cell 334 is daughter of cell 76.
# INFO:CellTracker:Tracked frame 68 in 0.21127085178159177 s.
# INFO:CellTracker:Tracking frame 69
# INFO:CellTracker:Tracked frame 69 in 0.2052815721835941 s.
# INFO:CellTracker:Tracking frame 70
# INFO:CellTracker:Created new track for cell 335.
# INFO:CellTracker:Detected division! Cell 335 is daughter of cell 293.
# INFO:CellTracker:Created new track for cell 336.
# INFO:CellTracker:Detected division! Cell 336 is daughter of cell 293.
# INFO:CellTracker:Tracked frame 70 in 0.22214903589338064 s.
# INFO:CellTracker:Tracking frame 71
# INFO:CellTracker:Created new track for cell 337.
# INFO:CellTracker:Detected division! Cell 337 is daughter of cell 132.
# INFO:CellTracker:Created new track for cell 338.
# INFO:CellTracker:Detected division! Cell 338 is daughter of cell 82.
# INFO:CellTracker:Created new track for cell 339.
# INFO:CellTracker:Detected division! Cell 339 is daughter of cell 82.
# INFO:CellTracker:Created new track for cell 340.
# INFO:CellTracker:Created new track for cell 341.
# INFO:CellTracker:Detected division! Cell 341 is daughter of cell 132.
# INFO:CellTracker:Tracked frame 71 in 0.22433724906295538 s.
# INFO:CellTracker:Tracking frame 72
# INFO:CellTracker:Created new track for cell 342.
# INFO:CellTracker:Created new track for cell 343.
# INFO:CellTracker:Detected division! Cell 343 is daughter of cell 113.
# INFO:CellTracker:Created new track for cell 344.
# INFO:CellTracker:Created new track for cell 345.
# INFO:CellTracker:Detected division! Cell 345 is daughter of cell 113.
# INFO:CellTracker:Tracked frame 72 in 0.22719093901105225 s.
# INFO:CellTracker:Tracking frame 73
# INFO:CellTracker:Created new track for cell 346.
# INFO:CellTracker:Created new track for cell 347.
# INFO:CellTracker:Detected division! Cell 347 is daughter of cell 144.
# INFO:CellTracker:Created new track for cell 348.
# INFO:CellTracker:Detected division! Cell 348 is daughter of cell 144.
# INFO:CellTracker:Created new track for cell 349.
# INFO:CellTracker:Detected division! Cell 349 is daughter of cell 91.
# INFO:CellTracker:Created new track for cell 350.
# INFO:CellTracker:Detected division! Cell 350 is daughter of cell 91.
# INFO:CellTracker:Tracked frame 73 in 0.23403452802449465 s.
# INFO:CellTracker:Tracking frame 74
# INFO:CellTracker:Created new track for cell 351.
# INFO:CellTracker:Detected division! Cell 351 is daughter of cell 157.
# INFO:CellTracker:Created new track for cell 352.
# INFO:CellTracker:Detected division! Cell 352 is daughter of cell 169.
# INFO:CellTracker:Created new track for cell 353.
# INFO:CellTracker:Created new track for cell 354.
# INFO:CellTracker:Detected division! Cell 354 is daughter of cell 169.
# INFO:CellTracker:Tracked frame 74 in 0.22976814093999565 s.
# INFO:CellTracker:Tracking frame 75
# INFO:CellTracker:Created new track for cell 356.
# INFO:CellTracker:Tracked frame 75 in 0.2123963579069823 s.
# INFO:CellTracker:Tracking frame 76
# INFO:CellTracker:Created new track for cell 357.
# INFO:CellTracker:Detected division! Cell 357 is daughter of cell 158.
# INFO:CellTracker:Created new track for cell 358.
# INFO:CellTracker:Detected division! Cell 358 is daughter of cell 158.
# INFO:CellTracker:Tracked frame 76 in 0.22163907811045647 s.
# INFO:CellTracker:Tracking frame 77
# INFO:CellTracker:Created new track for cell 359.
# INFO:CellTracker:Created new track for cell 360.
# INFO:CellTracker:Created new track for cell 361.
# INFO:CellTracker:Detected division! Cell 361 is daughter of cell 155.
# INFO:CellTracker:Created new track for cell 362.
# INFO:CellTracker:Detected division! Cell 362 is daughter of cell 185.
# INFO:CellTracker:Created new track for cell 363.
# INFO:CellTracker:Created new track for cell 364.
# INFO:CellTracker:Tracked frame 77 in 0.2485811309888959 s.
# INFO:CellTracker:Tracking frame 78
# INFO:CellTracker:Created new track for cell 367.
# INFO:CellTracker:Detected division! Cell 367 is daughter of cell 32.
# INFO:CellTracker:Created new track for cell 368.
# INFO:CellTracker:Detected division! Cell 368 is daughter of cell 160.
# INFO:CellTracker:Created new track for cell 369.
# INFO:CellTracker:Detected division! Cell 369 is daughter of cell 160.
# INFO:CellTracker:Created new track for cell 370.
# INFO:CellTracker:Detected division! Cell 370 is daughter of cell 128.
# INFO:CellTracker:Created new track for cell 371.
# INFO:CellTracker:Detected division! Cell 371 is daughter of cell 128.
# INFO:CellTracker:Tracked frame 78 in 0.24597158888354897 s.
# INFO:CellTracker:Tracking frame 79
# INFO:CellTracker:Created new track for cell 373.
# INFO:CellTracker:Created new track for cell 374.
# INFO:CellTracker:Detected division! Cell 374 is daughter of cell 168.
# INFO:CellTracker:Created new track for cell 375.
# INFO:CellTracker:Detected division! Cell 375 is daughter of cell 168.
# INFO:CellTracker:Created new track for cell 376.
# INFO:CellTracker:Detected division! Cell 376 is daughter of cell 78.
# INFO:CellTracker:Created new track for cell 377.
# INFO:CellTracker:Detected division! Cell 377 is daughter of cell 95.
# INFO:CellTracker:Created new track for cell 378.
# INFO:CellTracker:Detected division! Cell 378 is daughter of cell 95.
# INFO:CellTracker:Tracked frame 79 in 0.2663327627815306 s.
# INFO:CellTracker:Tracking frame 80
# INFO:CellTracker:Created new track for cell 380.
# INFO:CellTracker:Created new track for cell 381.
# INFO:CellTracker:Detected division! Cell 381 is daughter of cell 151.
# INFO:CellTracker:Created new track for cell 382.
# INFO:CellTracker:Detected division! Cell 382 is daughter of cell 151.
# INFO:CellTracker:Tracked frame 80 in 0.24436090514063835 s.
# INFO:CellTracker:Tracking frame 81
# INFO:CellTracker:Created new track for cell 383.
# INFO:CellTracker:Detected division! Cell 383 is daughter of cell 114.
# INFO:CellTracker:Created new track for cell 384.
# INFO:CellTracker:Detected division! Cell 384 is daughter of cell 180.
# INFO:CellTracker:Tracked frame 81 in 0.24249957990832627 s.
# INFO:CellTracker:Tracking frame 82
# INFO:CellTracker:Created new track for cell 387.
# INFO:CellTracker:Detected division! Cell 387 is daughter of cell 364.
# INFO:CellTracker:Created new track for cell 388.
# INFO:CellTracker:Detected division! Cell 388 is daughter of cell 150.
# INFO:CellTracker:Created new track for cell 389.
# INFO:CellTracker:Detected division! Cell 389 is daughter of cell 199.
# INFO:CellTracker:Created new track for cell 390.
# INFO:CellTracker:Created new track for cell 391.
# INFO:CellTracker:Created new track for cell 392.
# INFO:CellTracker:Created new track for cell 393.
# INFO:CellTracker:Detected division! Cell 393 is daughter of cell 150.
# INFO:CellTracker:Tracked frame 82 in 0.2627909949515015 s.
# INFO:CellTracker:Tracking frame 83
# INFO:CellTracker:Created new track for cell 394.
# INFO:CellTracker:Detected division! Cell 394 is daughter of cell 164.
# INFO:CellTracker:Created new track for cell 395.
# INFO:CellTracker:Detected division! Cell 395 is daughter of cell 164.
# INFO:CellTracker:Created new track for cell 396.
# INFO:CellTracker:Created new track for cell 397.
# INFO:CellTracker:Created new track for cell 398.
# INFO:CellTracker:Tracked frame 83 in 0.25998438289389014 s.
# INFO:CellTracker:Tracking frame 84
# INFO:CellTracker:Created new track for cell 399.
# INFO:CellTracker:Detected division! Cell 399 is daughter of cell 167.
# INFO:CellTracker:Created new track for cell 400.
# INFO:CellTracker:Tracked frame 84 in 0.23738528788089752 s.
# INFO:CellTracker:Tracking frame 85
# INFO:CellTracker:Created new track for cell 402.
# INFO:CellTracker:Detected division! Cell 402 is daughter of cell 193.
# INFO:CellTracker:Created new track for cell 403.
# INFO:CellTracker:Detected division! Cell 403 is daughter of cell 193.
# INFO:CellTracker:Tracked frame 85 in 0.2371289380826056 s.
# INFO:CellTracker:Tracking frame 86
# INFO:CellTracker:Created new track for cell 404.
# INFO:CellTracker:Detected division! Cell 404 is daughter of cell 186.
# INFO:CellTracker:Tracked frame 86 in 0.23491313611157238 s.
# INFO:CellTracker:Tracking frame 87
# INFO:CellTracker:Created new track for cell 406.
# INFO:CellTracker:Detected division! Cell 406 is daughter of cell 197.
# INFO:CellTracker:Created new track for cell 407.
# INFO:CellTracker:Detected division! Cell 407 is daughter of cell 161.
# INFO:CellTracker:Created new track for cell 408.
# INFO:CellTracker:Detected division! Cell 408 is daughter of cell 209.
# INFO:CellTracker:Created new track for cell 409.
# INFO:CellTracker:Detected division! Cell 409 is daughter of cell 209.
# INFO:CellTracker:Created new track for cell 410.
# INFO:CellTracker:Detected division! Cell 410 is daughter of cell 161.
# INFO:CellTracker:Created new track for cell 411.
# INFO:CellTracker:Created new track for cell 412.
# INFO:CellTracker:Tracked frame 87 in 0.2735062900464982 s.
# INFO:CellTracker:Tracking frame 88
# INFO:CellTracker:Created new track for cell 413.
# INFO:CellTracker:Created new track for cell 414.
# INFO:CellTracker:Created new track for cell 415.
# INFO:CellTracker:Tracked frame 88 in 0.2710956269875169 s.
# INFO:CellTracker:Tracking frame 89
# INFO:CellTracker:Created new track for cell 416.
# INFO:CellTracker:Detected division! Cell 416 is daughter of cell 162.
# INFO:CellTracker:Created new track for cell 417.
# INFO:CellTracker:Detected division! Cell 417 is daughter of cell 162.
# INFO:CellTracker:Tracked frame 89 in 0.2582881501875818 s.
# INFO:CellTracker:Tracking frame 90
# INFO:CellTracker:Created new track for cell 418.
# INFO:CellTracker:Detected division! Cell 418 is daughter of cell 172.
# INFO:CellTracker:Created new track for cell 419.
# INFO:CellTracker:Detected division! Cell 419 is daughter of cell 172.
# INFO:CellTracker:Created new track for cell 420.
# INFO:CellTracker:Detected division! Cell 420 is daughter of cell 292.
# INFO:CellTracker:Created new track for cell 421.
# INFO:CellTracker:Detected division! Cell 421 is daughter of cell 292.
# INFO:CellTracker:Tracked frame 90 in 0.2735712891444564 s.
# INFO:CellTracker:Tracking frame 91
# INFO:CellTracker:Created new track for cell 422.
# INFO:CellTracker:Created new track for cell 423.
# INFO:CellTracker:Detected division! Cell 423 is daughter of cell 213.
# INFO:CellTracker:Created new track for cell 424.
# INFO:CellTracker:Created new track for cell 425.
# INFO:CellTracker:Detected division! Cell 425 is daughter of cell 353.
# INFO:CellTracker:Created new track for cell 426.
# INFO:CellTracker:Detected division! Cell 426 is daughter of cell 353.
# INFO:CellTracker:Created new track for cell 427.
# INFO:CellTracker:Detected division! Cell 427 is daughter of cell 412.
# INFO:CellTracker:Created new track for cell 428.
# INFO:CellTracker:Tracked frame 91 in 0.29053645418025553 s.
# INFO:CellTracker:Tracked all 92 frames in 17.78484301781282 s.
# INFO:root:Converting image dtype to float
# INFO:CellTracker:Tracking frame 1
# INFO:CellTracker:Created new track for cell 81.
# INFO:CellTracker:Created new track for cell 82.
# INFO:CellTracker:Created new track for cell 83.
# INFO:CellTracker:Tracked frame 1 in 0.11685115494765341 s.
# INFO:CellTracker:Tracking frame 2
# INFO:CellTracker:Created new track for cell 84.
# INFO:CellTracker:Created new track for cell 85.
# INFO:CellTracker:Created new track for cell 86.
# INFO:CellTracker:Detected division! Cell 86 is daughter of cell 46.
# INFO:CellTracker:Created new track for cell 87.
# INFO:CellTracker:Detected division! Cell 87 is daughter of cell 54.
# INFO:CellTracker:Created new track for cell 88.
# INFO:CellTracker:Detected division! Cell 88 is daughter of cell 54.
# INFO:CellTracker:Tracked frame 2 in 0.12457069009542465 s.
# INFO:CellTracker:Tracking frame 3
# INFO:CellTracker:Created new track for cell 89.
# INFO:CellTracker:Detected division! Cell 89 is daughter of cell 37.
# INFO:CellTracker:Created new track for cell 90.
# INFO:CellTracker:Tracked frame 3 in 0.11334499693475664 s.
# INFO:CellTracker:Tracking frame 4
# INFO:CellTracker:Created new track for cell 91.
# INFO:CellTracker:Created new track for cell 92.
# INFO:CellTracker:Created new track for cell 93.
# INFO:CellTracker:Detected division! Cell 93 is daughter of cell 25.
# INFO:CellTracker:Created new track for cell 94.
# INFO:CellTracker:Detected division! Cell 94 is daughter of cell 25.
# INFO:CellTracker:Created new track for cell 95.
# INFO:CellTracker:Detected division! Cell 95 is daughter of cell 50.
# INFO:CellTracker:Created new track for cell 96.
# INFO:CellTracker:Detected division! Cell 96 is daughter of cell 50.
# INFO:CellTracker:Tracked frame 4 in 0.12578471703454852 s.
# INFO:CellTracker:Tracking frame 5
# INFO:CellTracker:Created new track for cell 97.
# INFO:CellTracker:Detected division! Cell 97 is daughter of cell 65.
# INFO:CellTracker:Created new track for cell 98.
# INFO:CellTracker:Detected division! Cell 98 is daughter of cell 65.
# INFO:CellTracker:Tracked frame 5 in 0.11691226507537067 s.
# INFO:CellTracker:Tracking frame 6
# INFO:CellTracker:Created new track for cell 99.
# INFO:CellTracker:Detected division! Cell 99 is daughter of cell 11.
# INFO:CellTracker:Created new track for cell 100.
# INFO:CellTracker:Detected division! Cell 100 is daughter of cell 11.
# INFO:CellTracker:Created new track for cell 101.
# INFO:CellTracker:Created new track for cell 102.
# INFO:CellTracker:Tracked frame 6 in 0.13022698205895722 s.
# INFO:CellTracker:Tracking frame 7
# INFO:CellTracker:Created new track for cell 103.
# INFO:CellTracker:Tracked frame 7 in 0.11510176095180213 s.
# INFO:CellTracker:Tracking frame 8
# INFO:CellTracker:Created new track for cell 104.
# INFO:CellTracker:Detected division! Cell 104 is daughter of cell 5.
# INFO:CellTracker:Created new track for cell 105.
# INFO:CellTracker:Detected division! Cell 105 is daughter of cell 5.
# INFO:CellTracker:Tracked frame 8 in 0.12419896107167006 s.
# INFO:CellTracker:Tracking frame 9
# INFO:CellTracker:Tracked frame 9 in 0.11798310093581676 s.
# INFO:CellTracker:Tracking frame 10
# INFO:CellTracker:Created new track for cell 106.
# INFO:CellTracker:Detected division! Cell 106 is daughter of cell 28.
# INFO:CellTracker:Created new track for cell 107.
# INFO:CellTracker:Detected division! Cell 107 is daughter of cell 28.
# INFO:CellTracker:Created new track for cell 108.
# INFO:CellTracker:Detected division! Cell 108 is daughter of cell 35.
# INFO:CellTracker:Created new track for cell 109.
# INFO:CellTracker:Detected division! Cell 109 is daughter of cell 35.
# INFO:CellTracker:Created new track for cell 110.
# INFO:CellTracker:Detected division! Cell 110 is daughter of cell 70.
# INFO:CellTracker:Tracked frame 10 in 0.12251847703009844 s.
# INFO:CellTracker:Tracking frame 11
# INFO:CellTracker:Created new track for cell 112.
# INFO:CellTracker:Detected division! Cell 112 is daughter of cell 4.
# INFO:CellTracker:Created new track for cell 113.
# INFO:CellTracker:Created new track for cell 114.
# INFO:CellTracker:Created new track for cell 115.
# INFO:CellTracker:Detected division! Cell 115 is daughter of cell 9.
# INFO:CellTracker:Created new track for cell 116.
# INFO:CellTracker:Detected division! Cell 116 is daughter of cell 9.
# INFO:CellTracker:Created new track for cell 117.
# INFO:CellTracker:Created new track for cell 118.
# INFO:CellTracker:Detected division! Cell 118 is daughter of cell 67.
# INFO:CellTracker:Created new track for cell 119.
# INFO:CellTracker:Detected division! Cell 119 is daughter of cell 67.
# INFO:CellTracker:Tracked frame 11 in 0.13766024797223508 s.
# INFO:CellTracker:Tracking frame 12
# INFO:CellTracker:Created new track for cell 120.
# INFO:CellTracker:Created new track for cell 121.
# INFO:CellTracker:Tracked frame 12 in 0.13258534390479326 s.
# INFO:CellTracker:Tracking frame 13
# INFO:CellTracker:Created new track for cell 122.
# INFO:CellTracker:Tracked frame 13 in 0.12666500406339765 s.
# INFO:CellTracker:Tracking frame 14
# INFO:CellTracker:Created new track for cell 123.
# INFO:CellTracker:Created new track for cell 124.
# INFO:CellTracker:Detected division! Cell 124 is daughter of cell 19.
# INFO:CellTracker:Created new track for cell 125.
# INFO:CellTracker:Detected division! Cell 125 is daughter of cell 19.
# INFO:CellTracker:Created new track for cell 126.
# INFO:CellTracker:Created new track for cell 127.
# ...
# INFO:CellTracker:Created new track for cell 300.
# INFO:CellTracker:Created new track for cell 301.
# INFO:CellTracker:Tracked frame 45 in 0.2085588041227311 s.
# INFO:CellTracker:Tracking frame 46
# INFO:CellTracker:Created new track for cell 302.
# INFO:CellTracker:Created new track for cell 303.
# INFO:CellTracker:Detected division! Cell 303 is daughter of cell 34.
# INFO:CellTracker:Created new track for cell 304.
# INFO:CellTracker:Detected division! Cell 304 is daughter of cell 34.
# INFO:CellTracker:Created new track for cell 305.
# INFO:CellTracker:Detected division! Cell 305 is daughter of cell 97.
# INFO:CellTracker:Created new track for cell 306.
# INFO:CellTracker:Detected division! Cell 306 is daughter of cell 97.
# INFO:CellTracker:Tracked frame 46 in 0.22193352202884853 s.
# INFO:CellTracker:Tracking frame 47
# INFO:CellTracker:Created new track for cell 307.
# INFO:CellTracker:Detected division! Cell 307 is daughter of cell 112.
# INFO:CellTracker:Created new track for cell 308.
# INFO:CellTracker:Detected division! Cell 308 is daughter of cell 112.
# INFO:CellTracker:Created new track for cell 309.
# INFO:CellTracker:Detected division! Cell 309 is daughter of cell 291.
# INFO:CellTracker:Created new track for cell 310.
# INFO:CellTracker:Created new track for cell 311.
# INFO:CellTracker:Detected division! Cell 311 is daughter of cell 84.
# INFO:CellTracker:Created new track for cell 312.
# INFO:CellTracker:Tracked frame 47 in 0.24725748086348176 s.
# INFO:CellTracker:Tracking frame 48
# INFO:CellTracker:Created new track for cell 313.
# INFO:CellTracker:Created new track for cell 314.
# INFO:CellTracker:Detected division! Cell 314 is daughter of cell 120.
# INFO:CellTracker:Tracked frame 48 in 0.22301125689409673 s.
# INFO:CellTracker:Tracking frame 49
# INFO:CellTracker:Created new track for cell 315.
# INFO:CellTracker:Detected division! Cell 315 is daughter of cell 169.
# INFO:CellTracker:Created new track for cell 316.
# INFO:CellTracker:Detected division! Cell 316 is daughter of cell 123.
# INFO:CellTracker:Tracked frame 49 in 0.21283580013550818 s.
# INFO:CellTracker:Tracking frame 50
# INFO:CellTracker:Tracked frame 50 in 0.20131593593396246 s.
# INFO:CellTracker:Tracking frame 51
# INFO:CellTracker:Created new track for cell 318.
# INFO:CellTracker:Detected division! Cell 318 is daughter of cell 125.
# INFO:CellTracker:Tracked frame 51 in 0.20831682393327355 s.
# INFO:CellTracker:Tracking frame 52
# INFO:CellTracker:Created new track for cell 320.
# INFO:CellTracker:Detected division! Cell 320 is daughter of cell 108.
# INFO:CellTracker:Created new track for cell 321.
# INFO:CellTracker:Tracked frame 52 in 0.2143663850147277 s.
# INFO:CellTracker:Tracking frame 53
# INFO:CellTracker:Created new track for cell 323.
# INFO:CellTracker:Detected division! Cell 323 is daughter of cell 126.
# INFO:CellTracker:Created new track for cell 324.
# INFO:CellTracker:Detected division! Cell 324 is daughter of cell 126.
# INFO:CellTracker:Tracked frame 53 in 0.21356452791951597 s.
# INFO:CellTracker:Tracking frame 54
# INFO:CellTracker:Created new track for cell 325.
# INFO:CellTracker:Created new track for cell 326.
# INFO:CellTracker:Detected division! Cell 326 is daughter of cell 134.
# INFO:CellTracker:Created new track for cell 327.
# INFO:CellTracker:Detected division! Cell 327 is daughter of cell 134.
# INFO:CellTracker:Created new track for cell 328.
# INFO:CellTracker:Detected division! Cell 328 is daughter of cell 168.
# INFO:CellTracker:Created new track for cell 329.
# INFO:CellTracker:Detected division! Cell 329 is daughter of cell 80.
# INFO:CellTracker:Created new track for cell 330.
# INFO:CellTracker:Detected division! Cell 330 is daughter of cell 80.
# INFO:CellTracker:Tracked frame 54 in 0.24528478714637458 s.
# INFO:CellTracker:Tracking frame 55
# INFO:CellTracker:Created new track for cell 332.
# INFO:CellTracker:Detected division! Cell 332 is daughter of cell 167.
# INFO:CellTracker:Created new track for cell 333.
# INFO:CellTracker:Detected division! Cell 333 is daughter of cell 122.
# INFO:CellTracker:Created new track for cell 334.
# INFO:CellTracker:Detected division! Cell 334 is daughter of cell 92.
# INFO:CellTracker:Created new track for cell 335.
# INFO:CellTracker:Detected division! Cell 335 is daughter of cell 92.
# INFO:CellTracker:Created new track for cell 336.
# INFO:CellTracker:Detected division! Cell 336 is daughter of cell 137.
# INFO:CellTracker:Created new track for cell 337.
# INFO:CellTracker:Tracked frame 55 in 0.2567796010989696 s.
# INFO:CellTracker:Tracking frame 56
# INFO:CellTracker:Created new track for cell 340.
# INFO:CellTracker:Created new track for cell 341.
# INFO:CellTracker:Created new track for cell 342.
# INFO:CellTracker:Tracked frame 56 in 0.23594174697063863 s.
# INFO:CellTracker:Tracking frame 57
# INFO:CellTracker:Created new track for cell 343.
# INFO:CellTracker:Created new track for cell 344.
# INFO:CellTracker:Detected division! Cell 344 is daughter of cell 207.
# INFO:CellTracker:Created new track for cell 345.
# INFO:CellTracker:Detected division! Cell 345 is daughter of cell 207.
# INFO:CellTracker:Created new track for cell 346.
# INFO:CellTracker:Tracked frame 57 in 0.24419566104188561 s.
# INFO:CellTracker:Tracking frame 58
# INFO:CellTracker:Created new track for cell 347.
# INFO:CellTracker:Created new track for cell 348.
# INFO:CellTracker:Detected division! Cell 348 is daughter of cell 221.
# INFO:CellTracker:Created new track for cell 349.
# INFO:CellTracker:Detected division! Cell 349 is daughter of cell 221.
# INFO:CellTracker:Created new track for cell 350.
# INFO:CellTracker:Detected division! Cell 350 is daughter of cell 118.
# INFO:CellTracker:Created new track for cell 351.
# INFO:CellTracker:Created new track for cell 352.
# INFO:CellTracker:Tracked frame 58 in 0.25323686213232577 s.
# INFO:CellTracker:Tracking frame 59
# INFO:CellTracker:Created new track for cell 353.
# INFO:CellTracker:Detected division! Cell 353 is daughter of cell 198.
# INFO:CellTracker:Created new track for cell 354.
# INFO:CellTracker:Detected division! Cell 354 is daughter of cell 198.
# INFO:CellTracker:Created new track for cell 355.
# INFO:CellTracker:Created new track for cell 356.
# INFO:CellTracker:Detected division! Cell 356 is daughter of cell 337.
# INFO:CellTracker:Tracked frame 59 in 0.24382529291324317 s.
# INFO:CellTracker:Tracking frame 60
# INFO:CellTracker:Created new track for cell 358.
# INFO:CellTracker:Detected division! Cell 358 is daughter of cell 133.
# INFO:CellTracker:Created new track for cell 359.
# INFO:CellTracker:Created new track for cell 360.
# INFO:CellTracker:Detected division! Cell 360 is daughter of cell 30.
# INFO:CellTracker:Created new track for cell 361.
# INFO:CellTracker:Detected division! Cell 361 is daughter of cell 142.
# INFO:CellTracker:Tracked frame 60 in 0.2508507710881531 s.
# INFO:CellTracker:Tracking frame 61
# INFO:CellTracker:Created new track for cell 365.
# INFO:CellTracker:Created new track for cell 366.
# INFO:CellTracker:Detected division! Cell 366 is daughter of cell 209.
# INFO:CellTracker:Created new track for cell 367.
# INFO:CellTracker:Detected division! Cell 367 is daughter of cell 205.
# INFO:CellTracker:Tracked frame 61 in 0.25026403088122606 s.
# INFO:CellTracker:Tracking frame 62
# INFO:CellTracker:Created new track for cell 370.
# INFO:CellTracker:Detected division! Cell 370 is daughter of cell 179.
# INFO:CellTracker:Created new track for cell 371.
# INFO:CellTracker:Detected division! Cell 371 is daughter of cell 179.
# INFO:CellTracker:Created new track for cell 372.
# INFO:CellTracker:Detected division! Cell 372 is daughter of cell 196.
# INFO:CellTracker:Created new track for cell 373.
# INFO:CellTracker:Detected division! Cell 373 is daughter of cell 196.
# INFO:CellTracker:Created new track for cell 374.
# INFO:CellTracker:Detected division! Cell 374 is daughter of cell 197.
# INFO:CellTracker:Created new track for cell 375.
# INFO:CellTracker:Detected division! Cell 375 is daughter of cell 197.
# INFO:CellTracker:Tracked frame 62 in 0.2644100780598819 s.
# INFO:CellTracker:Tracking frame 63
# INFO:CellTracker:Tracked frame 63 in 0.22992918593809009 s.
# INFO:CellTracker:Tracking frame 64
# INFO:CellTracker:Tracked frame 64 in 0.22116665309295058 s.
# INFO:CellTracker:Tracking frame 65
# INFO:CellTracker:Created new track for cell 376.
# INFO:CellTracker:Created new track for cell 377.
# INFO:CellTracker:Created new track for cell 378.
# INFO:CellTracker:Detected division! Cell 378 is daughter of cell 220.
# INFO:CellTracker:Tracked frame 65 in 0.25342028215527534 s.
# INFO:CellTracker:Tracking frame 66
# INFO:CellTracker:Created new track for cell 379.
# INFO:CellTracker:Created new track for cell 380.
# INFO:CellTracker:Detected division! Cell 380 is daughter of cell 227.
# INFO:CellTracker:Tracked frame 66 in 0.24149833992123604 s.
# INFO:CellTracker:Tracking frame 67
# INFO:CellTracker:Created new track for cell 381.
# INFO:CellTracker:Created new track for cell 382.
# INFO:CellTracker:Tracked frame 67 in 0.2452883468940854 s.
# INFO:CellTracker:Tracking frame 68
# INFO:CellTracker:Created new track for cell 383.
# INFO:CellTracker:Created new track for cell 384.
# INFO:CellTracker:Tracked frame 68 in 0.2535382320638746 s.
# INFO:CellTracker:Tracking frame 69
# INFO:CellTracker:Created new track for cell 385.
# INFO:CellTracker:Detected division! Cell 385 is daughter of cell 219.
# INFO:CellTracker:Created new track for cell 386.
# INFO:CellTracker:Detected division! Cell 386 is daughter of cell 219.
# INFO:CellTracker:Created new track for cell 387.
# INFO:CellTracker:Tracked frame 69 in 0.258665214991197 s.
# INFO:CellTracker:Tracking frame 70
# INFO:CellTracker:Created new track for cell 388.
# INFO:CellTracker:Detected division! Cell 388 is daughter of cell 203.
# INFO:CellTracker:Created new track for cell 389.
# INFO:CellTracker:Detected division! Cell 389 is daughter of cell 203.
# INFO:CellTracker:Created new track for cell 390.
# INFO:CellTracker:Detected division! Cell 390 is daughter of cell 222.
# INFO:CellTracker:Created new track for cell 391.
# INFO:CellTracker:Tracked frame 70 in 0.26975015201605856 s.
# INFO:CellTracker:Tracking frame 71
# INFO:CellTracker:Created new track for cell 393.
# INFO:CellTracker:Created new track for cell 394.
# INFO:CellTracker:Created new track for cell 395.
# INFO:CellTracker:Created new track for cell 396.
# INFO:CellTracker:Detected division! Cell 396 is daughter of cell 195.
# INFO:CellTracker:Tracked frame 71 in 0.2652045451104641 s.
# INFO:CellTracker:Tracking frame 72
# INFO:CellTracker:Created new track for cell 397.
# INFO:CellTracker:Created new track for cell 398.
# INFO:CellTracker:Tracked frame 72 in 0.2487319470383227 s.
# INFO:CellTracker:Tracking frame 73
# INFO:CellTracker:Created new track for cell 399.
# INFO:CellTracker:Tracked frame 73 in 0.2411054209806025 s.
# INFO:CellTracker:Tracking frame 74
# INFO:CellTracker:Created new track for cell 400.
# INFO:CellTracker:Detected division! Cell 400 is daughter of cell 148.
# INFO:CellTracker:Created new track for cell 401.
# INFO:CellTracker:Tracked frame 74 in 0.2521473260130733 s.
# INFO:CellTracker:Tracking frame 75
# INFO:CellTracker:Created new track for cell 403.
# INFO:CellTracker:Detected division! Cell 403 is daughter of cell 145.
# INFO:CellTracker:Created new track for cell 404.
# INFO:CellTracker:Detected division! Cell 404 is daughter of cell 145.
# INFO:CellTracker:Tracked frame 75 in 0.25430094986222684 s.
# INFO:CellTracker:Tracking frame 76
# INFO:CellTracker:Tracked frame 76 in 0.2403378440067172 s.
# INFO:CellTracker:Tracking frame 77
# INFO:CellTracker:Tracked frame 77 in 0.23394390288740396 s.
# INFO:CellTracker:Tracking frame 78
# INFO:CellTracker:Created new track for cell 405.
# INFO:CellTracker:Created new track for cell 406.
# INFO:CellTracker:Detected division! Cell 406 is daughter of cell 192.
# INFO:CellTracker:Created new track for cell 407.
# INFO:CellTracker:Detected division! Cell 407 is daughter of cell 237.
# INFO:CellTracker:Created new track for cell 408.
# INFO:CellTracker:Detected division! Cell 408 is daughter of cell 237.
# INFO:CellTracker:Created new track for cell 409.
# INFO:CellTracker:Tracked frame 78 in 0.2792820008471608 s.
# INFO:CellTracker:Tracking frame 79
# INFO:CellTracker:Created new track for cell 411.
# INFO:CellTracker:Created new track for cell 412.
# INFO:CellTracker:Tracked frame 79 in 0.25176366814412177 s.
# INFO:CellTracker:Tracking frame 80
# INFO:CellTracker:Created new track for cell 413.
# INFO:CellTracker:Created new track for cell 414.
# INFO:CellTracker:Detected division! Cell 414 is daughter of cell 163.
# INFO:CellTracker:Created new track for cell 415.
# INFO:CellTracker:Detected division! Cell 415 is daughter of cell 191.
# INFO:CellTracker:Created new track for cell 416.
# INFO:CellTracker:Created new track for cell 417.
# INFO:CellTracker:Tracked frame 80 in 0.2886966411024332 s.
# INFO:CellTracker:Tracking frame 81
# INFO:CellTracker:Created new track for cell 420.
# INFO:CellTracker:Created new track for cell 421.
# INFO:CellTracker:Created new track for cell 422.
# INFO:CellTracker:Created new track for cell 423.
# INFO:CellTracker:Created new track for cell 424.
# INFO:CellTracker:Detected division! Cell 424 is daughter of cell 199.
# INFO:CellTracker:Created new track for cell 425.
# INFO:CellTracker:Detected division! Cell 425 is daughter of cell 199.
# INFO:CellTracker:Created new track for cell 426.
# INFO:CellTracker:Detected division! Cell 426 is daughter of cell 235.
# INFO:CellTracker:Created new track for cell 427.
# INFO:CellTracker:Detected division! Cell 427 is daughter of cell 235.
# INFO:CellTracker:Created new track for cell 428.
# INFO:CellTracker:Created new track for cell 429.
# INFO:CellTracker:Tracked frame 81 in 0.3289960250258446 s.
# INFO:CellTracker:Tracking frame 82
# INFO:CellTracker:Created new track for cell 430.
# INFO:CellTracker:Created new track for cell 431.
# INFO:CellTracker:Created new track for cell 432.
# INFO:CellTracker:Created new track for cell 433.
# INFO:CellTracker:Created new track for cell 434.
# INFO:CellTracker:Tracked frame 82 in 0.29129858291707933 s.
# INFO:CellTracker:Tracking frame 83
# INFO:CellTracker:Created new track for cell 435.
# INFO:CellTracker:Tracked frame 83 in 0.2515099188312888 s.
# INFO:CellTracker:Tracking frame 84
# INFO:CellTracker:Created new track for cell 436.
# INFO:CellTracker:Created new track for cell 437.
# INFO:CellTracker:Detected division! Cell 437 is daughter of cell 95.
# INFO:CellTracker:Tracked frame 84 in 0.26558313402347267 s.
# INFO:CellTracker:Tracking frame 85
# INFO:CellTracker:Created new track for cell 438.
# INFO:CellTracker:Created new track for cell 439.
# INFO:CellTracker:Tracked frame 85 in 0.2682881457731128 s.
# INFO:CellTracker:Tracking frame 86
# INFO:CellTracker:Created new track for cell 440.
# INFO:CellTracker:Detected division! Cell 440 is daughter of cell 130.
# INFO:CellTracker:Created new track for cell 441.
# INFO:CellTracker:Detected division! Cell 441 is daughter of cell 130.
# INFO:CellTracker:Tracked frame 86 in 0.2688441341742873 s.
# INFO:CellTracker:Tracking frame 87
# INFO:CellTracker:Created new track for cell 442.
# INFO:CellTracker:Created new track for cell 443.
# INFO:CellTracker:Tracked frame 87 in 0.27151008509099483 s.
# INFO:CellTracker:Tracking frame 88
# INFO:CellTracker:Created new track for cell 444.
# INFO:CellTracker:Created new track for cell 445.
# INFO:CellTracker:Created new track for cell 446.
# INFO:CellTracker:Tracked frame 88 in 0.276868999004364 s.
# INFO:CellTracker:Tracking frame 89
# INFO:CellTracker:Created new track for cell 447.
# INFO:CellTracker:Tracked frame 89 in 0.25102720013819635 s.
# INFO:CellTracker:Tracking frame 90
# INFO:CellTracker:Created new track for cell 448.
# INFO:CellTracker:Detected division! Cell 448 is daughter of cell 430.
# INFO:CellTracker:Tracked frame 90 in 0.25221980712376535 s.
# INFO:CellTracker:Tracking frame 91
# INFO:CellTracker:Created new track for cell 449.
# INFO:CellTracker:Created new track for cell 450.
# INFO:CellTracker:Detected division! Cell 450 is daughter of cell 234.
# INFO:CellTracker:Created new track for cell 451.
# INFO:CellTracker:Detected division! Cell 451 is daughter of cell 69.
# INFO:CellTracker:Tracked frame 91 in 0.27192829409614205 s.
# INFO:CellTracker:Tracked all 92 frames in 19.85241439100355 s.

# %% [markdown]
# # 2. Evaluation

# %%
import glob
import os
import re
import subprocess

import numpy as np
import pandas as pd

from deepcell_tracking.metrics import TrackingMetrics

# %%
data_dir = 'ctc-data'
gt_seg_dir = os.path.join(data_dir, 'SEG_GT')
pred_seg_dir = os.path.join(data_dir, 'SEG_PRED')

pattern = re.compile('\d{3}_GT')
data_ids = [f.split('_')[0] for f in os.listdir(gt_seg_dir) if pattern.fullmatch(f)]

node_match_threshold = 0.6

ctc_software = '../CTC_Evaluation_Software'
operating_system = 'Linux' # or 'Mac' or 'Win'
num_digits = '3'

# %%
benchmarks = []

for results_dir, s in zip([gt_seg_dir, pred_seg_dir], ['GT', 'Caliban']):
    for data_id in data_ids:
        results = {
            'model': f'Caliban - {s}',
            'data_id': os.path.splitext(data_id)[0]
        }
        gt_dir = os.path.join(results_dir, f'{data_id}_GT/TRA')
        res_dir = os.path.join(results_dir, f'{data_id}_RES')

        # Deepcell benchmarking
        m = TrackingMetrics.from_isbi_dirs(gt_dir, res_dir, threshold=node_match_threshold)
        results.update(m.stats)

        # CTC metrics
        for metric, path in [('DET', 'DETMeasure'), ('SEG', 'SEGMeasure'), ('TRA', 'TRAMeasure')]:
            p = subprocess.run([os.path.join(ctc_software, operating_system, path), results_dir, data_id, num_digits],
                               stdout=subprocess.PIPE)
            outstring = p.stdout

            try:
                val = float(outstring.decode('utf-8').split()[-1])
                results[metric] = val
            except:
                print('Benchmarking failure', path, results_dir, data_id)
                print(outstring.decode('utf-8'))

        benchmarks.append(results)

df = pd.DataFrame(benchmarks)
df.to_csv('ctc-benchmarks.csv')
# Out:
# missed node 1_23 division completely
# missed node 3_29 division completely
# missed node 4_20 division completely
# 7_5 out degree = 1, daughters mismatch.
# 10_5 out degree = 1, daughters mismatch.
# missed node 19_10 division completely
# missed node 27_22 division completely
# missed node 46_20 division completely
# 56_37 out degree = 1, daughters mismatch.
# missed node 62_5 division completely
# missed node 79_73 division completely
# missed node 80_78 division completely
# missed node 83_54 division completely
# missed node 97_34 division completely
# missed node 386_76 division completely
# missed node 107_46 division completely
# missed node 417_51 division completely
# missed node 120_60 division completely
# missed node 126_76 division completely
# missed node 419_60 division completely
# missed node 131_74 division completely
# missed node 144_73 division completely
# missed node 175_90 division completely
# 186_81 out degree = 1, daughters mismatch.
# missed node 255_63 division completely
# missed node 300_84 division completely
# missed node 347_90 division completely
# missed node 459_51 division completely
# missed node 16_7 division completely
# 17_19 out degree = 1, daughters mismatch.
# missed node 20_13 division completely
# missed node 21_1 division completely
# missed node 22_0 division completely
# 23_2 out degree = 1, daughters mismatch.
# missed node 26_0 division completely
# 27_42 out degree = 1, daughters mismatch.
# missed node 36_3 division completely
# missed node 38_12 division completely
# missed node 40_1 division completely
# missed node 50_30 division completely
# 52_55 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 56_64 division completely
# missed node 60_21 division completely
# missed node 68_15 division completely
# 72_46 out degree = 1, daughters mismatch.
# missed node 79_5 division completely
# 85_54 out degree = 1, daughters mismatch.
# missed node 87_12 division completely
# missed node 91_0 division completely
# missed node 99_0 division completely
# missed node 475_0 division completely
# missed node 102_56 division completely
# missed node 105_30 division completely
# 106_48 out degree = 1, daughters mismatch.
# 107_57 out degree = 1, daughters mismatch.
# missed node 476_38 division completely
# 114_50 out degree = 1, daughters mismatch.
# 436_53 out degree = 1, daughters mismatch.
# missed node 151_64 division completely
# 470_59 out degree = 1, daughters mismatch.
# 181_70 out degree = 1, daughters mismatch.
# missed node 143_55 division completely
# missed node 193_60 division completely
# missed node 430_69 division completely
# missed node 208_67 division completely
# missed node 239_87 division completely
# missed node 494_88 division completely
# missed node 500_57 division completely
# missed node 547_54 division completely
# corrected division 547_54 as a frameshift division not an error
# missed node 1_23 division completely
# missed node 3_29 division completely
# missed node 4_20 division completely
# missed node 10_5 division completely
# missed node 11_43 division completely
# missed node 12_25 division completely
# missed node 19_10 division completely
# missed node 32_77 division completely
# missed node 46_20 division completely
# missed node 55_13 division completely
# missed node 59_17 division completely
# 60_26 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 62_5 division completely
# missed node 69_59 division completely
# missed node 71_40 division completely
# 72_62 out degree = 1, daughters mismatch.
# missed node 79_73 division completely
# missed node 80_78 division completely
# missed node 83_54 division completely
# 89_37 out degree = 1, daughters mismatch.
# missed node 97_34 division completely
# missed node 386_76 division completely
# missed node 100_43 division completely
# missed node 107_46 division completely
# missed node 108_48 division completely
# missed node 417_51 division completely
# missed node 110_67 division completely
# 378_54 out degree = 1, daughters mismatch.
# missed node 425_47 division completely
# missed node 120_60 division completely
# missed node 121_55 division completely
# missed node 126_76 division completely
# missed node 131_74 division completely
# missed node 132_65 division completely
# 150_75 out degree = 1, daughters mismatch.
# missed node 151_73 division completely
# 163_89 out degree = 1, daughters mismatch.
# missed node 114_80 division completely
# missed node 175_90 division completely
# 186_81 out degree = 1, daughters mismatch.
# missed node 255_63 division completely
# missed node 300_84 division completely
# missed node 347_90 division completely
# missed node 459_51 division completely
# corrected division 108_48 as a frameshift division not an error
# corrected division 425_47 as a frameshift division not an error
# corrected division 100_43 as a frameshift division not an error
# missed node 6_7 division completely
# missed node 13_36 division completely
# missed node 22_0 division completely
# missed node 26_0 division completely
# missed node 27_42 division completely
# 36_3 out degree = 1, daughters mismatch.
# missed node 40_1 division completely
# missed node 41_31 division completely
# missed node 47_2 division completely
# 50_30 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 52_55 division completely
# missed node 56_64 division completely
# 58_13 out degree = 1, daughters mismatch.
# missed node 60_21 division completely
# missed node 67_22 division completely
# missed node 68_15 division completely
# missed node 71_38 division completely
# missed node 72_46 division completely
# missed node 73_10 division completely
# 76_16 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 78_0 division completely
# missed node 79_5 division completely
# 82_2 out degree = 1, daughters mismatch.
# missed node 86_10 division completely
# missed node 87_12 division completely
# missed node 91_0 division completely
# missed node 99_0 division completely
# missed node 475_0 division completely
# missed node 102_56 division completely
# 103_46 out degree = 1, daughters mismatch, parents mismatch.
# 105_30 out degree = 1, daughters mismatch.
# 106_48 out degree = 1, daughters mismatch.
# 107_57 out degree = 1, daughters mismatch.
# missed node 151_64 division completely
# missed node 155_77 division completely
# 181_70 out degree = 1, daughters mismatch.
# missed node 143_55 division completely
# 205_64 out degree = 1, daughters mismatch.
# missed node 208_67 division completely
# missed node 239_87 division completely
# missed node 494_88 division completely
# missed node 500_57 division completely
# missed node 512_53 division completely
# corrected division 86_10 as a frameshift division not an error
# corrected division 41_31 as a frameshift division not an error
# corrected division 47_2 as a frameshift division not an error

# %%
df
# Out:
#                model data_id  correct_division  mismatch_division  \
# 0       Caliban - GT     001               133                  4
# 1       Caliban - GT     002                93                 12
# 2  Caliban - Caliban     001               120                  7
# 3  Caliban - Caliban     002                93                 11
#
#    false_positive_division  false_negative_division  total_divisions  aa_tp  \
# 0                        8                       24              161  13455
# 1                       18                       28              133  17183
# 2                       14                       34              161  13424
# 3                       14                       29              133  17129
#
#    aa_total  te_tp  te_total       DET       SEG       TRA
# 0     13508  13891     13944  1.000000  1.000000  0.999344
# 1     17465  17667     17949  1.000000  1.000000  0.998996
# 2     13508  13859     13944  0.993768  0.896498  0.993366
# 3     17465  17610     17949  0.993638  0.896924  0.992289
