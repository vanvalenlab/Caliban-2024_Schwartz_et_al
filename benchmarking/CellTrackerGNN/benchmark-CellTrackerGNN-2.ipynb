# %% [markdown]
# <div class="alert alert-block alert-info"> <b>NOTE</b> Please select the kernel <code>Python [conda env:gnn-tf]</code> for this notebook. </div>

# %% [markdown]
# # 2. Inference - Segmentation

# %%
import os
import re
import subprocess

# %%
software_dir = 'software'
data_dir = 'data'

models = [
    'Fluo-N2DL-HeLa',
    'Fluo-N2DH-SIM+'
]

pattern = re.compile('\d{3}')
data_ids = [f for f in os.listdir(os.path.join(data_dir, models[0])) if pattern.fullmatch(f)]

# %% [markdown]
# Predict segmentations

# %%
fov = '25'
min_size = '10'
max_size = '1000000'
edge_dist = '2'
sigmoid_thresh = '0.4'
min_center_size = '5'
pre_sequence_frames = '4'
data_format = 'NCHW'

code_seg = os.path.join(software_dir, 'seg_code/new_version')
seg_model_dir = os.path.join(software_dir, 'parameters/Seg_Models')

# %%
process_output = []
for m in models:
    print('------', m, '------')
    for i in data_ids:
        print(i)
        p = subprocess.run(
            ['python', os.path.join(code_seg, 'Inference2D.py'),
             '--gpu', '0',
             '--model_path', os.path.join(seg_model_dir, m),
             '--sequence_path', os.path.join(data_dir, m, i),
             '--output_path', os.path.join(data_dir, m, f'{i}_SEG_RES'),
             '--edge_dist', edge_dist,
             '--min_cell_size', min_size,
             '--max_cell_size', max_size,
             '--fov', fov,
             '--centers_sigmoid_threshold', sigmoid_thresh,
             '--min_center_size', min_center_size,
             '--pre_sequence_frames', pre_sequence_frames,
             '--data_format', data_format,
             '--save_intermediate',
             '--save_intermediate_path', os.path.join(data_dir, m, f'{i}_SEG_intermediate')
            ],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE)
        process_output.append(p)
# Out:
# ------ Fluo-N2DL-HeLa ------
# 011
# 002
# 009
# 003
# 012
# 007
# 001
# 006
# 010
# 004
# 008
# 005
# ------ Fluo-N2DH-SIM+ ------
# 011
# 002
# 009
# 003
# 012
# 007
# 001
# 006
# 010
# 004
# 008
# 005

# %%
import tensorflow as tf
tf.config.list_physical_devices(
    device_type=None
)
# Out:
# 2022-12-05 22:38:51.122142: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-12-05 22:38:53.087660: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# 2022-12-05 22:38:53.088564: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-12-05 22:38:53.119235: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:0a:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-12-05 22:38:53.119288: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-12-05 22:38:53.119603: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-12-05 22:38:53.119717: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-12-05 22:38:53.122365: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-12-05 22:38:53.122806: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-12-05 22:38:53.125279: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-12-05 22:38:53.125375: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-12-05 22:38:53.125444: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-12-05 22:38:53.125457: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
process_output
# Out:
# [CompletedProcess(args=['python', 'software/seg_code/new_version/Inference2D.py', '--gpu', '0', '--model_path', 'software/parameters/Seg_Models/Fluo-N2DL-HeLa', '--sequence_path', 'data/Fluo-N2DL-HeLa/011', '--output_path', 'data/Fluo-N2DL-HeLa/011_SEG_RES', '--edge_dist', '2', '--min_cell_size', '10', '--max_cell_size', '1000000', '--fov', '25', '--centers_sigmoid_threshold', '0.4', '--min_center_size', '5', '--pre_sequence_frames', '4', '--data_format', 'NCHW', '--save_intermediate', '--save_intermediate_path', 'data/Fluo-N2DL-HeLa/011_SEG_intermediate'], returncode=1, stdout=b'2022-12-05 22:33:51: Restored from software/parameters/Seg_Models/Fluo-N2DL-HeLa/model.ckpt\nDone!\n2022-12-05 22:33:51: Done\n', stderr=b'2022-12-05 22:33:46.109771: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0\n2022-12-05 22:33:51.038390: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set\n2022-12-05 22:33:51.040325: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1\n2022-12-05 22:33:51.072308: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties: \npciBusID: 0000:0a:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1\ncoreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s\n2022-12-05 22:33:51.072374: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0\n2022-12-05 22:33:51.073317: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcublas.so.11\'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:33:51.073454: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcublasLt.so.11\'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:33:51.097646: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10\n2022-12-05 22:33:51.103615: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10\n2022-12-05 22:33:51.150338: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10\n2022-12-05 22:33:51.150634: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcusparse.so.11\'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:33:51.150753: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcudnn.so.8\'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:33:51.150773: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.\nSkipping registering GPU devices...\n2022-12-05 22:33:51.151884: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI  ...
#  CompletedProcess(args=['python', 'software/seg_code/new_version/Inference2D.py', '--gpu', '0', '--model_path', 'software/parameters/Seg_Models/Fluo-N2DL-HeLa', '--sequence_path', 'data/Fluo-N2DL-HeLa/002', '--output_path', 'data/Fluo-N2DL-HeLa/002_SEG_RES', '--edge_dist', '2', '--min_cell_size', '10', '--max_cell_size', '1000000', '--fov', '25', '--centers_sigmoid_threshold', '0.4', '--min_center_size', '5', '--pre_sequence_frames', '4', '--data_format', 'NCHW', '--save_intermediate', '--save_intermediate_path', 'data/Fluo-N2DL-HeLa/002_SEG_intermediate'], returncode=1, stdout=b'2022-12-05 22:33:56: Restored from software/parameters/Seg_Models/Fluo-N2DL-HeLa/model.ckpt\nDone!\n2022-12-05 22
I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI  ...
#  CompletedProcess(args=['python', 'software/seg_code/new_version/Inference2D.py', '--gpu', '0', '--model_path', 'software/parameters/Seg_Models/Fluo-N2DL-HeLa', '--sequence_path', 'data/Fluo-N2DL-HeLa/008', '--output_path', 'data/Fluo-N2DL-HeLa/008_SEG_RES', '--edge_dist', '2', '--min_cell_size', '10', '--max_cell_size', '1000000', '--fov', '25', '--centers_sigmoid_threshold', '0.4', '--min_center_size', '5', '--pre_sequence_frames', '4', '--data_format', 'NCHW', '--save_intermediate', '--save_intermediate_path', 'data/Fluo-N2DL-HeLa/008_SEG_intermediate'], returncode=1, stdout=b'2022-12-05 22:34:44: Restored from software/parameters/Seg_Models/Fluo-N2DL-HeLa/model.ckpt\nDone!\n2022-12-05 22:34:45: Done\n', stderr=b'2022-12-05 22:34:41.203900: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0\n2022-12-05 22:34:44.321558: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set\n2022-12-05 22:34:44.322554: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1\n2022-12-05 22:34:44.351329: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties: \npciBusID: 0000:0a:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1\ncoreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s\n2022-12-05 22:34:44.351406: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0\n2022-12-05 22:34:44.351677: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcublas.so.11\'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:34:44.351807: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcublasLt.so.11\'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:34:44.354688: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10\n2022-12-05 22:34:44.355201: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10\n2022-12-05 22:34:44.357636: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10\n2022-12-05 22:34:44.357750: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcusparse.so.11\'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:34:44.357819: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcudnn.so.8\'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:34:44.357833: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.\nSkipping registering GPU devices...\n2022-12-05 22:34:44.358169: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI  ...
# ...
#  CompletedProcess(args=['python', 'software/seg_code/new_version/Inference2D.py', '--gpu', '0', '--model_path', 'software/parameters/Seg_Models/Fluo-N2DH-SIM+', '--sequence_path', 'data/Fluo-N2DH-SIM+/004', '--output_path', 'data/Fluo-N2DH-SIM+/004_SEG_RES', '--edge_dist', '2', '--min_cell_size', '10', '--max_cell_size', '1000000', '--fov', '25', '--centers_sigmoid_threshold', '0.4', '--min_center_size', '5', '--pre_sequence_frames', '4', '--data_format', 'NCHW', '--save_intermediate', '--save_intermediate_path', 'data/Fluo-N2DH-SIM+/004_SEG_intermediate'], returncode=1, stdout=b'2022-12-05 22:35:41: Restored from software/parameters/Seg_Models/Fluo-N2DH-SIM+/model.ckpt\nDone!\n2022-12-05 22:35:42: Done\n', stderr=b'2022-12-05 22:35:38.603138: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0\n2022-12-05 22:35:41.690582: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set\n2022-12-05 22:35:41.691510: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1\n2022-12-05 22:35:41.722889: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties: \npciBusID: 0000:0a:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1\ncoreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s\n2022-12-05 22:35:41.722942: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0\n2022-12-05 22:35:41.723154: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcublas.so.11\'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:35:41.723229: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcublasLt.so.11\'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:35:41.725218: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10\n2022-12-05 22:35:41.725549: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10\n2022-12-05 22:35:41.727937: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10\n2022-12-05 22:35:41.728038: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcusparse.so.11\'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:35:41.728109: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcudnn.so.8\'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:35:41.728124: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.\nSkipping registering GPU devices...\n2022-12-05 22:35:41.728476: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI  ...
#  CompletedProcess(args=['python', 'software/seg_code/new_version/Inference2D.py', '--gpu', '0', '--model_path', 'software/parameters/Seg_Models/Fluo-N2DH-SIM+', '--sequence_path', 'data/Fluo-N2DH-SIM+/008', '--output_path', 'data/Fluo-N2DH-SIM+/008_SEG_RES', '--edge_dist', '2', '--min_cell_size', '10', '--max_cell_size', '1000000', '--fov', '25', '--centers_sigmoid_threshold', '0.4', '--min_center_size', '5', '--pre_sequence_frames', '4', '--data_format', 'NCHW', '--save_intermediate', '--save_intermediate_path', 'data/Fluo-N2DH-SIM+/008_SEG_intermediate'], returncode=1, stdout=b'2022-12-05 22:35:46: Restored from software/parameters/Seg_Models/Fluo-N2DH-SIM+/model.ckpt\nDone!\n2022-12-05 22:35:47: Done\n', stderr=b'2022-12-05 22:35:43.635257: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0\n2022-12-05 22:35:46.665446: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set\n2022-12-05 22:35:46.666352: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1\n2022-12-05 22:35:46.695392: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties: \npciBusID: 0000:0a:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1\ncoreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s\n2022-12-05 22:35:46.695442: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0\n2022-12-05 22:35:46.695705: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcublas.so.11\'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:35:46.695791: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcublasLt.so.11\'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:35:46.698080: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10\n2022-12-05 22:35:46.698451: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10\n2022-12-05 22:35:46.701010: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10\n2022-12-05 22:35:46.701105: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcusparse.so.11\'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:35:46.701171: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcudnn.so.8\'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:35:46.701186: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.\nSkipping registering GPU devices...\n2022-12-05 22:35:46.701506: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI  ...
#  CompletedProcess(args=['python', 'software/seg_code/new_version/Inference2D.py', '--gpu', '0', '--model_path', 'software/parameters/Seg_Models/Fluo-N2DH-SIM+', '--sequence_path', 'data/Fluo-N2DH-SIM+/005', '--output_path', 'data/Fluo-N2DH-SIM+/005_SEG_RES', '--edge_dist', '2', '--min_cell_size', '10', '--max_cell_size', '1000000', '--fov', '25', '--centers_sigmoid_threshold', '0.4', '--min_center_size', '5', '--pre_sequence_frames', '4', '--data_format', 'NCHW', '--save_intermediate', '--save_intermediate_path', 'data/Fluo-N2DH-SIM+/005_SEG_intermediate'], returncode=1, stdout=b'2022-12-05 22:35:51: Restored from software/parameters/Seg_Models/Fluo-N2DH-SIM+/model.ckpt\nDone!\n2022-12-05 22:35:52: Done\n', stderr=b'2022-12-05 22:35:48.541222: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0\n2022-12-05 22:35:51.547535: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set\n2022-12-05 22:35:51.548457: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1\n2022-12-05 22:35:51.579833: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties: \npciBusID: 0000:0a:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1\ncoreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s\n2022-12-05 22:35:51.579883: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0\n2022-12-05 22:35:51.580108: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcublas.so.11\'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:35:51.580188: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcublasLt.so.11\'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:35:51.582234: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10\n2022-12-05 22:35:51.582593: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10\n2022-12-05 22:35:51.585108: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10\n2022-12-05 22:35:51.585220: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcusparse.so.11\'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:35:51.585300: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library \'libcudnn.so.8\'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/gnn-tf/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64\n2022-12-05 22:35:51.585316: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.\nSkipping registering GPU devices...\n2022-12-05 22:35:51.585673: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI  ...
