# %% [markdown]
# <div class="alert alert-block alert-info"> <b>NOTE</b> Please select the kernel <code>Python [conda env: deepcell]</code> for this notebook. </div>

# %% [markdown]
# # 1. Data Preparation
# Resave data as a set of tiff files in order to match conventions expected by TracX.

# %%
import os
import sys

import numpy as np
import tensorflow as tf
from tifffile import imwrite

from deepcell.applications import NuclearSegmentation
from deepcell_tracking.trk_io import load_trks

sys.path.append('..')
import utils

# %%
data_dir = 'ctc-data'
ctc_dc_dir = os.path.join(data_dir, 'CTC', 'seg-dc')
ctc_gt_dir = os.path.join(data_dir, 'CTC', 'seg-gt')
raw_dir = os.path.join(data_dir, 'raw')
seg_gt_dir = os.path.join(data_dir, 'seg-gt')
seg_dc_dir = os.path.join(data_dir, 'seg-dc')

for d in [raw_dir, seg_gt_dir, seg_dc_dir, ctc_dc_dir, ctc_gt_dir]:
    if not os.path.exists(d):
        os.makedirs(d)

# %% [markdown]
# Load the test split of the tracking data

# %%
files = ['../../data/Fluo-N2DL-Hela-test/Fluo-N2DL-HeLa-test-01.trk', '../../data/Fluo-N2DL-Hela-test/Fluo-N2DL-HeLa-test-02.trk']
X, y, lineages = [], [], []
for f in files:
    data = load_trks(f)
    X.append(data['X'])
    y.append(data['y'])
    lineages.append(data['lineages'][0])

data = {
    'X': np.stack(X, axis=0),
    'y': np.stack(y, axis=0),
    'lineages': lineages
}

# %% [markdown]
# Load the DeepCell nuclear segmentation model to test the algorithm on predicted instead of ground truth segmentations

# %%
app = NuclearSegmentation.from_version(version='1.1')
# Out:
# INFO:root:Checking for cached data
# INFO:root:Checking NuclearSegmentation-8.tar.gz against provided file_hash...
# INFO:root:NuclearSegmentation-8.tar.gz with hash 507be21f0e34e59adae689f58cc03ccb already available.
# INFO:root:Extracting /Users/morganschwartz/.deepcell/models/NuclearSegmentation-8.tar.gz
# INFO:root:Successfully extracted /Users/morganschwartz/.deepcell/models/NuclearSegmentation-8.tar.gz into /Users/morganschwartz/.deepcell/models
# 2024-07-08 15:21:22.509823: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-07-08 15:21:22.509953: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1 Max
#
# systemMemory: 64.00 GB
# maxCacheSize: 24.00 GB
#
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
# ChannelName_positionXXYYZZZ_timeTTTT.tif
name_template = '{}_position{:02}{:02}000_time{:05}.tif'

# %%
for batch_no in range(len(data['lineages'])):
    # Build subdirectories for data
    raw_subdir = os.path.join(raw_dir, '{:03}'.format(batch_no + 1))
    seg_gt_subdir = os.path.join(seg_gt_dir, '{:03}'.format(batch_no + 1))
    seg_dc_subdir = os.path.join(seg_dc_dir, '{:03}'.format(batch_no + 1))

    # Create directories if needed
    for d in (raw_subdir, seg_gt_subdir, seg_dc_subdir):
        if not os.path.exists(d):
            os.makedirs(d)

    # Pull out relevant data for this batch
    X = data['X'][batch_no]
    y = data['y'][batch_no]
    lineage = data['lineages'][batch_no]

    # Correct discontiguous tracks, which are not allowed by CTC
    y, lineage = utils.convert_to_contiguous(y, lineage)

    # Determine position of zero padding for removal
    slc = utils.find_zero_padding(X)
    X = X[slc]
    y = y[slc]

    # Determine which frames are zero padding
    frames = np.sum(y, axis=(1,2)) # True if image not blank
    good_frames = np.where(frames)[0]
    X = X[:len(good_frames)]
    y = y[:len(good_frames)]

    # Generate deepcell predictions
    y_pred = app.predict(X)

    # Save GT in CTC format
    for d in [ctc_dc_dir, ctc_gt_dir]:
        utils.save_ctc_gt(d, batch_no + 1, y[good_frames], lineage)

    # Position info for naming convention
    x_pos = batch_no + 1
    y_pos = 1

    # Save each frame of the movie as an individual tif
    channel = 0 # These images should only have one channel
    for i in range(X.shape[0]):
        name_raw = os.path.join(raw_subdir, name_template.format('nuclear', x_pos, y_pos, i+1))
        name_gt_mask = os.path.join(seg_gt_subdir, name_template.format('mask-gt', x_pos, y_pos, i+1))
        name_dc_mask = os.path.join(seg_dc_subdir, name_template.format('mask-dc', x_pos, y_pos, i+1))

        imwrite(name_raw, X[i, ..., channel])
        imwrite(name_gt_mask, y[i, ..., channel])
        imwrite(name_dc_mask, y_pred[i, ..., channel])
# Out:
# INFO:root:Converting image dtype to float
# 2024-07-08 15:21:46.128105: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-07-08 15:21:47.227646: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# ...
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/ce725a5f-c761-11ee-a4ec-b6ef2fd8d87b/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"

# %% [markdown]
# # 2. Tracking
# 1. Open Matlab > 2020 and open the TracX folder
# 2. From the Matlab terminal, run the following
# `addpath(genpath('tracx'));`
# 3. Open the `run_tracx.m` script in matlab and press run.

# %% [markdown]
# # 3. Evaluate

# %%
import glob
import os
import subprocess

import numpy as np
import pandas as pd
from tifffile import imread, imwrite

from deepcell_tracking.isbi_utils import load_tiffs
from deepcell_tracking.metrics import TrackingMetrics

# %%
data_dir = 'ctc-data'
ctc_dir = os.path.join(data_dir, 'CTC')
ctc_dc_dir = os.path.join(ctc_dir, 'seg-dc')
ctc_gt_dir = os.path.join(ctc_dir, 'seg-gt')
seg_gt_dir = os.path.join(data_dir, 'seg-gt')
seg_dc_dir = os.path.join(data_dir, 'seg-dc')

ids = os.listdir(seg_gt_dir)

node_match_threshold = 0.6

ctc_software = '../CTC_Evaluation_Software'
operating_system = 'Mac' # or 'Mac' or 'Win'
num_digits = '3'

# %%
def create_new_lineage(y):
    """Create a blank lineage dict for ids that have already been
    linked via IOU. Link only based on overlap,
    so there are no divisions/daughters/parents/deaths
    Args:
        y: (np.array) label image stack.
    Returns:
        dict: a nested dict (lineage for .trk)
    """
    new_lineage = {}
    for i, frame in enumerate(y):
        # Add to frames field if ID exists
        cells_in_frame = np.unique(frame)
        cells_in_frame = np.delete(
            cells_in_frame, np.where(cells_in_frame == 0)
        )
        cells_in_frame = list(cells_in_frame)

        for cell in cells_in_frame:
            cell = int(cell)
            if cell in new_lineage:
                new_lineage[cell]["frames"].append(i)

            # Or create a new dict because its a new cell
            else:
                new_lineage[cell] = {
                    "label": cell,
                    "frames": [i],
                    "daughters": [],
                    "capped": False,
                    "frame_div": None,
                    "parent": None,
                }

    return new_lineage

# %% [markdown]
# Load each movie, relabel the mask to match the new tracking ids and create the lineage information

# %%
for res_dir in [seg_gt_dir, seg_dc_dir]:
    for i in ids:
        print(res_dir, i)
        # Find results path
        cc_path = glob.glob(os.path.join(res_dir, i, '*CellCycleResults*'))[0]
        t_path = glob.glob(os.path.join(res_dir, i, '*TrackingResults*'))[0]

        # Load TracX results
        cc_res = pd.read_csv(cc_path, sep='\t')
        t_res = pd.read_csv(t_path, sep='\t')

        y_old = load_tiffs(os.path.join(res_dir, i))

        # Create a new y array with update cell ids
        y_new = np.zeros_like(y_old)
        for _, r in t_res.iterrows():
            id_new = int(r['track_index'])
            id_old = int(r['cell_index'])
            t = int(r['cell_frame']) - 1 # Time indexed starting at 1 in TracX
            y_new[t][y_old[t] == id_old] = id_new

        # Create lineage
        lineage = create_new_lineage(y_new)

        # Assign parents and daughters
        for _, r in cc_res.iterrows():
            tid = r['track']
            # Check if a parent should be added
            if r['parent'] != 0:
                lineage[tid]['parent'] = int(r['parent'])

            # Check of daughter should be added
            if not np.isnan(r['daughter']):
                lineage[tid]['daughters'].append(int(r['daughter']))
                lineage[tid]['frame_div'] = max(lineage[tid]['frames'])

        # Correct discontiguous tracks, which are not allowed by CTC
        y_new, lineage = utils.convert_to_contiguous(y_new, lineage)

        # Save results in CTC format
        utils.save_ctc_res(os.path.join(ctc_dir, os.path.basename(res_dir)), int(i), y_new, lineage)
# Out:
# ctc-data/seg-gt 001
# ctc-data/seg-gt 002
# ctc-data/seg-dc 001
# ctc-data/seg-dc 002

# %%
benchmarks = []

for results_dir, s in zip([ctc_gt_dir, ctc_dc_dir], ['GT', 'Deepcell']):
    for data_id in ids:
        print(data_id)
        results = {
            'model': f'TracX - {s}',
            'data_id': data_id
        }
        gt_dir = os.path.join(results_dir, f'{data_id}_GT/TRA')
        res_dir = os.path.join(results_dir, f'{data_id}_RES')

        # Deepcell benchmarking
        m = TrackingMetrics.from_isbi_dirs(gt_dir, res_dir, threshold=node_match_threshold)
        results.update(m.stats)

        # CTC metrics
        for metric, path in [('DET', 'DETMeasure'), ('SEG', 'SEGMeasure'), ('TRA', 'TRAMeasure')]:
            p = subprocess.run([os.path.join(ctc_software, operating_system, path), results_dir, data_id, num_digits],
                               stdout=subprocess.PIPE)
            outstring = p.stdout

            try:
                val = float(outstring.decode('utf-8').split()[-1])
                results[metric] = val
            except:
                print('Benchmarking failure', path, results_dir, data_id)
                print(outstring.decode('utf-8'))

        benchmarks.append(results)

df = pd.DataFrame(benchmarks)
df.to_csv('ctc-benchmarks.csv')
# Out:
# 001
# missed node 1_23 division completely
# 2_20 out degree = 1, daughters mismatch.
# missed node 3_29 division completely
# 4_20 out degree = 1, daughters mismatch.
# missed node 5_1 division completely
# missed node 6_7 division completely
# 7_5 out degree = 1, daughters mismatch.
# missed node 8_13 division completely
# missed node 9_3 division completely
# missed node 10_5 division completely
# missed node 11_43 division completely
# missed node 12_25 division completely
# missed node 13_3 division completely
# missed node 14_41 division completely
# missed node 15_45 division completely
# missed node 16_36 division completely
# missed node 17_58 division completely
# missed node 18_27 division completely
# missed node 19_10 division completely
# missed node 20_30 division completely
# missed node 21_25 division completely
# missed node 22_33 division completely
# 23_25 out degree = 1, daughters mismatch.
# missed node 24_51 division completely
# missed node 25_50 division completely
# missed node 26_22 division completely
# missed node 28_21 division completely
# missed node 29_14 division completely
# 30_25 out degree = 1, daughters mismatch.
# missed node 31_16 division completely
# missed node 32_77 division completely
# missed node 33_32 division completely
# missed node 34_42 division completely
# missed node 36_42 division completely
# 37_23 out degree = 1, daughters mismatch, parents mismatch.
# missed node 38_17 division completely
# missed node 39_37 division completely
# missed node 40_44 division completely
# missed node 41_24 division completely
# missed node 42_14 division completely
# missed node 43_20 division completely
# 45_15 out degree = 1, daughters mismatch.
# missed node 46_20 division completely
# missed node 47_16 division completely
# missed node 48_9 division completely
# missed node 49_10 division completely
# missed node 50_9 division completely
# missed node 51_16 division completely
# missed node 52_10 division completely
# missed node 53_9 division completely
# missed node 54_29 division completely
# missed node 55_13 division completely
# missed node 56_37 division completely
# missed node 57_15 division completely
# missed node 58_27 division completely
# missed node 59_17 division completely
# missed node 60_26 division completely
# missed node 62_5 division completely
# missed node 63_42 division completely
# missed node 64_32 division completely
# missed node 82_10 division completely
# missed node 66_39 division completely
# missed node 67_36 division completely
# missed node 68_40 division completely
# missed node 69_59 division completely
# missed node 70_52 division completely
# missed node 71_40 division completely
# missed node 72_62 division completely
# 73_53 out degree = 1, daughters mismatch.
# missed node 74_66 division completely
# missed node 76_54 division completely
# missed node 78_56 division completely
# missed node 407_56 division completely
# missed node 79_73 division completely
# missed node 80_78 division completely
# missed node 81_31 division completely
# missed node 83_54 division completely
# missed node 84_70 division completely
# missed node 85_59 division completely
# missed node 86_56 division completely
# missed node 87_57 division completely
# missed node 88_59 division completely
# missed node 89_37 division completely
# missed node 93_72 division completely
# 94_53 out degree = 1, daughters mismatch.
# missed node 97_34 division completely
# missed node 386_76 division completely
# 100_43 out degree = 1, daughters mismatch.
# missed node 102_56 division completely
# 103_56 out degree = 1, daughters mismatch.
# missed node 104_46 division completely
# 105_65 out degree = 1, daughters mismatch, parents mismatch.
# missed node 142_34 division completely
# missed node 106_53 division completely
# missed node 107_46 division completely
# missed node 417_51 division completely
# missed node 112_64 division completely
# missed node 113_54 division completely
# missed node 400_71 division completely
# missed node 117_61 division completely
# 118_49 out degree = 1, daughters mismatch.
# missed node 119_50 division completely
# missed node 378_54 division completely
# missed node 425_47 division completely
# 121_55 out degree = 1, daughters mismatch.
# missed node 122_61 division completely
# missed node 447_56 division completely
# missed node 115_63 division completely
# 126_76 out degree = 1, daughters mismatch.
# missed node 127_77 division completely
# missed node 128_70 division completely
# missed node 419_60 division completely
# missed node 131_74 division completely
# missed node 132_65 division completely
# 392_63 out degree = 1, daughters mismatch, parents mismatch.
# missed node 136_49 division completely
# missed node 138_72 division completely
# missed node 145_81 division completely
# missed node 394_76 division completely
# missed node 150_75 division completely
# missed node 151_73 division completely
# missed node 153_77 division completely
# missed node 154_86 division completely
# missed node 402_88 division completely
# missed node 156_82 division completely
# missed node 158_83 division completely
# missed node 160_78 division completely
# missed node 163_89 division completely
# missed node 165_44 division completely
# missed node 114_80 division completely
# missed node 166_78 division completely
# missed node 167_80 division completely
# missed node 169_54 division completely
# 173_76 out degree = 1, daughters mismatch.
# missed node 174_85 division completely
# missed node 175_90 division completely
# missed node 180_84 division completely
# missed node 186_81 division completely
# missed node 189_52 division completely
# missed node 195_86 division completely
# 197_90 out degree = 1, daughters mismatch.
# missed node 259_61 division completely
# missed node 255_63 division completely
# missed node 261_89 division completely
# missed node 442_69 division completely
# missed node 300_84 division completely
# missed node 311_90 division completely
# missed node 347_90 division completely
# 362_90 out degree = 1, daughters mismatch, parents mismatch.
# missed node 451_54 division completely
# missed node 457_41 division completely
# missed node 458_67 division completely
# missed node 459_51 division completely
# corrected division 394_76 as a frameshift division not an error
# corrected division 14_41 as a frameshift division not an error
# 002
# missed node 1_5 division completely
# missed node 3_10 division completely
# missed node 5_11 division completely
# missed node 6_7 division completely
# missed node 7_9 division completely
# missed node 8_29 division completely
# missed node 9_22 division completely
# missed node 10_56 division completely
# 11_11 out degree = 1, daughters mismatch.
# missed node 12_17 division completely
# missed node 13_36 division completely
# missed node 14_9 division completely
# missed node 15_38 division completely
# 16_7 out degree = 2, parents mismatch, gt and res degree equal.
# missed node 17_19 division completely
# missed node 18_18 division completely
# missed node 21_1 division completely
# 22_0 out degree = 1, daughters mismatch.
# missed node 23_2 division completely
# missed node 24_28 division completely
# missed node 25_25 division completely
# missed node 26_0 division completely
# missed node 27_42 division completely
# missed node 28_13 division completely
# missed node 30_13 division completely
# 31_11 out degree = 1, daughters mismatch.
# missed node 32_4 division completely
# 33_15 out degree = 1, daughters mismatch.
# missed node 35_15 division completely
# missed node 36_3 division completely
# missed node 37_33 division completely
# missed node 38_12 division completely
# missed node 39_32 division completely
# missed node 40_1 division completely
# missed node 42_14 division completely
# 43_53 out degree = 1, daughters mismatch.
# missed node 44_57 division completely
# 45_15 out degree = 2, parents mismatch, gt and res degree equal.
# missed node 46_31 division completely
# missed node 48_10 division completely
# missed node 49_7 division completely
# missed node 50_30 division completely
# missed node 52_55 division completely
# missed node 54_39 division completely
# missed node 55_21 division completely
# 56_64 out degree = 1, daughters mismatch.
# missed node 57_35 division completely
# 58_13 out degree = 1, daughters mismatch.
# missed node 60_21 division completely
# missed node 61_26 division completely
# missed node 62_12 division completely
# 63_11 out degree = 1, daughters mismatch.
# missed node 65_30 division completely
# missed node 66_5 division completely
# 67_22 out degree = 1, daughters mismatch.
# missed node 68_15 division completely
# missed node 71_38 division completely
# missed node 72_46 division completely
# missed node 73_10 division completely
# 75_16 out degree = 1, daughters mismatch.
# missed node 76_16 division completely
# missed node 78_0 division completely
# missed node 79_5 division completely
# missed node 82_2 division completely
# missed node 83_13 division completely
# missed node 84_23 division completely
# missed node 85_54 division completely
# missed node 87_12 division completely
# missed node 88_1 division completely
# missed node 91_0 division completely
# missed node 95_20 division completely
# 96_23 out degree = 1, daughters mismatch.
# missed node 99_0 division completely
# missed node 475_0 division completely
# missed node 100_39 division completely
# missed node 101_43 division completely
# missed node 102_56 division completely
# missed node 103_46 division completely
# missed node 105_30 division completely
# missed node 106_48 division completely
# 107_57 out degree = 1, daughters mismatch.
# missed node 111_51 division completely
# missed node 175_46 division completely
# missed node 443_40 division completely
# missed node 476_38 division completely
# missed node 482_39 division completely
# missed node 114_50 division completely
# missed node 116_54 division completely
# missed node 120_52 division completely
# missed node 122_85 division completely
# missed node 126_59 division completely
# missed node 436_53 division completely
# missed node 131_59 division completely
# missed node 134_45 division completely
# missed node 460_74 division completely
# missed node 151_64 division completely
# missed node 155_77 division completely
# missed node 158_53 division completely
# 160_48 out degree = 1, daughters mismatch.
# missed node 161_54 division completely
# missed node 470_59 division completely
# missed node 174_61 division completely
# missed node 176_77 division completely
# missed node 180_58 division completely
# missed node 181_70 division completely
# missed node 182_61 division completely
# missed node 183_61 division completely
# missed node 458_80 division completely
# missed node 187_69 division completely
# missed node 191_60 division completely
# missed node 143_55 division completely
# missed node 193_60 division completely
# missed node 203_42 division completely
# missed node 204_68 division completely
# missed node 205_64 division completely
# missed node 430_69 division completely
# missed node 208_67 division completely
# missed node 209_65 division completely
# missed node 224_45 division completely
# missed node 490_41 division completely
# 239_87 out degree = 1, daughters mismatch.
# missed node 494_88 division completely
# missed node 500_57 division completely
# missed node 510_77 division completely
# missed node 537_47 division completely
# missed node 547_54 division completely
# corrected division 430_69 as a frameshift division not an error
# corrected division 27_42 as a frameshift division not an error
# 001
# missed node 1_23 division completely
# 2_20 out degree = 1, daughters mismatch.
# missed node 3_29 division completely
# 4_20 out degree = 1, daughters mismatch.
# missed node 5_1 division completely
# missed node 6_7 division completely
# 7_5 out degree = 1, daughters mismatch.
# missed node 8_13 division completely
# missed node 9_3 division completely
# missed node 10_5 division completely
# missed node 11_43 division completely
# missed node 12_25 division completely
# missed node 13_3 division completely
# missed node 14_41 division completely
# missed node 15_45 division completely
# missed node 16_36 division completely
# missed node 17_58 division completely
# missed node 18_27 division completely
# missed node 19_10 division completely
# missed node 20_30 division completely
# missed node 21_25 division completely
# missed node 22_33 division completely
# 23_25 out degree = 1, daughters mismatch.
# missed node 24_51 division completely
# missed node 25_50 division completely
# missed node 26_22 division completely
# missed node 28_21 division completely
# missed node 29_14 division completely
# 30_25 out degree = 1, daughters mismatch.
# missed node 31_16 division completely
# missed node 32_77 division completely
# missed node 33_32 division completely
# missed node 34_42 division completely
# missed node 36_42 division completely
# 37_23 out degree = 1, daughters mismatch, parents mismatch.
# missed node 38_17 division completely
# missed node 39_37 division completely
# missed node 40_44 division completely
# missed node 41_24 division completely
# 42_14 out degree = 1, daughters mismatch.
# missed node 43_20 division completely
# 45_15 out degree = 1, daughters mismatch.
# missed node 46_20 division completely
# missed node 47_16 division completely
# missed node 48_9 division completely
# missed node 49_10 division completely
# missed node 50_9 division completely
# missed node 51_16 division completely
# missed node 52_10 division completely
# missed node 53_9 division completely
# missed node 54_29 division completely
# missed node 55_13 division completely
# missed node 56_37 division completely
# missed node 57_15 division completely
# missed node 58_27 division completely
# missed node 59_17 division completely
# missed node 60_26 division completely
# missed node 62_5 division completely
# missed node 63_42 division completely
# missed node 64_32 division completely
# missed node 82_10 division completely
# missed node 66_39 division completely
# missed node 67_36 division completely
# missed node 68_40 division completely
# missed node 69_59 division completely
# missed node 71_40 division completely
# missed node 72_62 division completely
# 73_53 out degree = 1, daughters mismatch.
# missed node 74_66 division completely
# missed node 76_54 division completely
# missed node 78_56 division completely
# missed node 407_56 division completely
# missed node 79_73 division completely
# missed node 80_78 division completely
# missed node 81_31 division completely
# missed node 83_54 division completely
# missed node 84_70 division completely
# 85_59 out degree = 1, daughters mismatch, parents mismatch.
# missed node 86_56 division completely
# missed node 87_57 division completely
# missed node 88_59 division completely
# missed node 89_37 division completely
# missed node 93_72 division completely
# missed node 97_34 division completely
# missed node 386_76 division completely
# missed node 100_43 division completely
# 102_56 out degree = 1, daughters mismatch, parents mismatch.
# missed node 103_56 division completely
# missed node 104_46 division completely
# 105_65 out degree = 1, daughters mismatch.
# missed node 142_34 division completely
# missed node 106_53 division completely
# missed node 107_46 division completely
# missed node 108_48 division completely
# missed node 417_51 division completely
# missed node 112_64 division completely
# missed node 113_54 division completely
# missed node 400_71 division completely
# missed node 117_61 division completely
# missed node 119_50 division completely
# missed node 378_54 division completely
# missed node 425_47 division completely
# missed node 120_60 division completely
# missed node 121_55 division completely
# missed node 122_61 division completely
# missed node 447_56 division completely
# missed node 115_63 division completely
# 126_76 out degree = 1, daughters mismatch.
# missed node 127_77 division completely
# 128_70 out degree = 2, parents mismatch, gt and res degree equal.
# missed node 419_60 division completely
# missed node 131_74 division completely
# missed node 132_65 division completely
# 392_63 out degree = 1, daughters mismatch, parents mismatch.
# missed node 136_49 division completely
# missed node 138_72 division completely
# missed node 145_81 division completely
# 394_76 out degree = 1, daughters mismatch.
# missed node 150_75 division completely
# missed node 151_73 division completely
# missed node 153_77 division completely
# missed node 154_86 division completely
# missed node 402_88 division completely
# missed node 156_82 division completely
# missed node 158_83 division completely
# missed node 160_78 division completely
# missed node 163_89 division completely
# missed node 165_44 division completely
# missed node 114_80 division completely
# missed node 166_78 division completely
# missed node 167_80 division completely
# missed node 169_54 division completely
# 173_76 out degree = 1, daughters mismatch.
# missed node 174_85 division completely
# missed node 175_90 division completely
# missed node 180_84 division completely
# missed node 186_81 division completely
# missed node 189_52 division completely
# missed node 195_86 division completely
# 197_90 out degree = 1, daughters mismatch.
# missed node 259_61 division completely
# missed node 255_63 division completely
# missed node 261_89 division completely
# missed node 442_69 division completely
# missed node 300_84 division completely
# missed node 311_90 division completely
# missed node 347_90 division completely
# 362_90 out degree = 2, parents mismatch, gt and res degree equal.
# missed node 451_54 division completely
# missed node 457_41 division completely
# missed node 458_67 division completely
# missed node 459_51 division completely
# corrected division 108_48 as a frameshift division not an error
# corrected division 425_47 as a frameshift division not an error
# corrected division 62_5 as a frameshift division not an error
# corrected division 100_43 as a frameshift division not an error
# 002
# missed node 1_5 division completely
# missed node 3_10 division completely
# missed node 5_11 division completely
# missed node 6_7 division completely
# missed node 7_9 division completely
# missed node 8_29 division completely
# missed node 9_22 division completely
# missed node 10_56 division completely
# 11_11 out degree = 1, daughters mismatch.
# missed node 12_17 division completely
# missed node 13_36 division completely
# missed node 14_9 division completely
# missed node 15_38 division completely
# missed node 17_19 division completely
# missed node 18_18 division completely
# 20_13 out degree = 1, daughters mismatch.
# missed node 21_1 division completely
# 22_0 out degree = 1, daughters mismatch.
# missed node 23_2 division completely
# missed node 24_28 division completely
# missed node 25_25 division completely
# 26_0 out degree = 1, daughters mismatch.
# missed node 27_42 division completely
# missed node 28_13 division completely
# missed node 30_13 division completely
# 31_11 out degree = 1, daughters mismatch.
# missed node 32_4 division completely
# 33_15 out degree = 1, daughters mismatch.
# missed node 35_15 division completely
# missed node 36_3 division completely
# missed node 37_33 division completely
# missed node 38_12 division completely
# missed node 39_32 division completely
# missed node 40_1 division completely
# missed node 41_31 division completely
# missed node 42_14 division completely
# 43_53 out degree = 1, daughters mismatch.
# missed node 44_57 division completely
# 45_15 out degree = 2, parents mismatch, gt and res degree equal.
# missed node 46_31 division completely
# missed node 47_2 division completely
# 48_10 out degree = 1, daughters mismatch.
# missed node 49_7 division completely
# missed node 50_30 division completely
# 52_55 out degree = 2, daughters mismatch, gt and res degree equal.
# missed node 54_39 division completely
# missed node 55_21 division completely
# missed node 56_64 division completely
# missed node 57_35 division completely
# 58_13 out degree = 1, daughters mismatch.
# missed node 60_21 division completely
# missed node 61_26 division completely
# missed node 62_12 division completely
# 63_11 out degree = 1, daughters mismatch.
# missed node 65_30 division completely
# missed node 66_5 division completely
# missed node 67_22 division completely
# missed node 68_15 division completely
# missed node 71_38 division completely
# missed node 72_46 division completely
# missed node 73_10 division completely
# 75_16 out degree = 1, daughters mismatch.
# missed node 76_16 division completely
# missed node 78_0 division completely
# missed node 79_5 division completely
# missed node 82_2 division completely
# missed node 83_13 division completely
# missed node 84_23 division completely
# missed node 85_54 division completely
# missed node 86_10 division completely
# missed node 87_12 division completely
# missed node 91_0 division completely
# missed node 95_20 division completely
# missed node 99_0 division completely
# missed node 475_0 division completely
# missed node 100_39 division completely
# missed node 101_43 division completely
# missed node 102_56 division completely
# missed node 103_46 division completely
# missed node 105_30 division completely
# missed node 106_48 division completely
# 107_57 out degree = 1, daughters mismatch.
# missed node 111_51 division completely
# missed node 175_46 division completely
# missed node 443_40 division completely
# missed node 476_38 division completely
# missed node 482_39 division completely
# missed node 114_50 division completely
# missed node 116_54 division completely
# missed node 120_52 division completely
# missed node 122_85 division completely
# missed node 126_59 division completely
# missed node 436_53 division completely
# missed node 131_59 division completely
# missed node 134_45 division completely
# missed node 460_74 division completely
# 151_64 out degree = 1, daughters mismatch.
# missed node 155_77 division completely
# missed node 158_53 division completely
# missed node 161_54 division completely
# missed node 470_59 division completely
# missed node 174_61 division completely
# missed node 176_77 division completely
# missed node 180_58 division completely
# missed node 181_70 division completely
# missed node 182_61 division completely
# missed node 183_61 division completely
# missed node 458_80 division completely
# missed node 187_69 division completely
# 191_60 out degree = 1, daughters mismatch.
# missed node 143_55 division completely
# missed node 193_60 division completely
# missed node 203_42 division completely
# missed node 204_68 division completely
# missed node 205_64 division completely
# missed node 430_69 division completely
# missed node 208_67 division completely
# missed node 209_65 division completely
# missed node 224_45 division completely
# missed node 490_41 division completely
# 239_87 out degree = 1, daughters mismatch.
# missed node 494_88 division completely
# missed node 500_57 division completely
# missed node 510_77 division completely
# missed node 537_47 division completely
# missed node 547_54 division completely
# corrected division 430_69 as a frameshift division not an error
# corrected division 86_10 as a frameshift division not an error
# corrected division 47_2 as a frameshift division not an error
